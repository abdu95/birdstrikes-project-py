# %%
import pandas as pd
import numpy as np

import requests
import json
from datetime import datetime

# %%
airports = pd.read_csv('airports.csv')

# %%
len(airports)
# Out:
# 55

# %%
df_cleaned = pd.read_csv('df_cleaned.csv')

# %%
df_cleaned
# Out:
#        Unnamed: 0  Record ID  Incident Year  Incident Month  Incident Day  \
# 0           32753     201559           2000               1             2
# 1           32759     202643           2000               1             3
# 2           32776     201103           2000               1             5
# 3           32781     202558           2000               1             6
# 4           32783     207369           2000               1             6
# ...           ...        ...            ...             ...           ...
# 20649      174089     365891           2015               9            30
# 20650      174093     366043           2015               9            30
# 20651      174094     366042           2015               9            30
# 20652      174100     365902           2015               9            30
# 20653      174101     365903           2015               9            30
#
#       Operator ID            Operator     Aircraft Aircraft Type  \
# 0             DAL     DELTA AIR LINES    B-737-300             A
# 1             COM     COMAIR AIRLINES      EMB-120             A
# 2             KAP            CAPE AIR        C-402             A
# 3             SWA  SOUTHWEST AIRLINES        B-737             A
# 4             TRS     AIRTRAN AIRWAYS      DC-9-30             A
# ...           ...                 ...          ...           ...
# 20649         FDX       FEDEX EXPRESS    B-757-200             A
# 20650         FDX       FEDEX EXPRESS        A-300             A
# 20651         AAL   AMERICAN AIRLINES        MD-83             A
# 20652         SWA  SOUTHWEST AIRLINES    B-737-700             A
# 20653         BUS            BUSINESS  CITATIONJET             A
#
#       Aircraft Make  ...  Flight Phase Visibility Precipitation  Height  \
# 0               148  ...  LANDING ROLL        DAY          NONE     0.0
# 1               332  ...  LANDING ROLL        DAY          NONE     0.0
# 2               226  ...  LANDING ROLL        DAY          NONE     0.0
# 3               148  ...  LANDING ROLL       DUSK          NONE     0.0
# 4               583  ...   TAKEOFF RUN        DAY          NONE     0.0
# ...             ...  ...           ...        ...           ...     ...
# 20649           148  ...      APPROACH      NIGHT          NONE  4700.0
# 20650           04A  ...      APPROACH      NIGHT          NONE  2000.0
# 20651           583  ...         CLIMB      NIGHT          NONE    10.0
# 20652           148  ...      APPROACH        DAY          NONE  5000.0
# 20653           226  ...         CLIMB        DAY          NONE  3000.0
#
#        Speed Distance Species ID         Species Name  Species Quantity  \
# 0      130.0      0.0      UNKBS   UNKNOWN SMALL BIRD              2-10
# 1      100.0      0.0       YM11                 CROW              2-10
# 2       55.0      0.0        I13                EGRET                 1
# 3      100.0      0.0      UNKBS   UNKNOWN SMALL BIRD                 1
# 4       80.0      0.0      O2111          ROCK PIGEON              2-10
# ...      ...      ...        ...                  ...               ...
# 20649  240.0      1.0      UNKBM  UNKNOWN MEDIUM BIRD                 1
# 20650  160.0      5.0      UNKBS   UNKNOWN SMALL BIRD                 1
# 20651  140.0      0.0      UNKBS   UNKNOWN SMALL BIRD                 1
# 20652  250.0     25.0      UNKBS   UNKNOWN SMALL BIRD                 1
# 20653  200.0      5.0      K1002       TURKEY VULTURE                 1
#
#          Flight Impact
# 0                OTHER
# 1                 NONE
# 2                 NONE
# 3                 NONE
# 4      ABORTED TAKEOFF
# ...                ...
# 20649             NONE
# 20650             NONE
# 20651             NONE
# 20652             NONE
# 20653             NONE
#
# [20654 rows x 25 columns]

# %%
airport_codes = pd.read_csv('airport-codes_csv.csv')

# %%
airport_codes
# Out:
#          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
# 57418  ZZ-0001        heliport                     Sealand Helipad
# 57419  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 57420     ZZZZ   small_airport             Satsuma IÅjima Airport
#
#        elevation_ft continent iso_country iso_region      municipality  \
# 0              11.0       NaN          US      US-PA          Bensalem
# 1            3435.0       NaN          US      US-KS             Leoti
# 2             450.0       NaN          US      US-AK      Anchor Point
# 3             820.0       NaN          US      US-AL           Harvest
# 4             237.0       NaN          US      US-AR           Newport
# ...             ...       ...         ...        ...               ...
# 57416           0.0        AS          CN      CN-21           Yingkou
# 57417           NaN        AS          CN      CN-21          Shenyang
# 57418          40.0        EU          GB     GB-ENG           Sealand
# 57419          11.0        AF          TF     TF-U-A  Grande Glorieuse
# 57420         338.0        AS          JP      JP-46      Mishima-Mura
#
#       gps_code iata_code local_code                              coordinates
# 0          00A       NaN        00A       -74.93360137939453, 40.07080078125
# 1         00AA       NaN       00AA                   -101.473911, 38.704022
# 2         00AK       NaN       00AK              -151.695999146, 59.94919968
# 3         00AL       NaN       00AL    -86.77030181884766, 34.86479949951172
# 4          NaN       NaN        NaN                      -91.254898, 35.6087
# ...        ...       ...        ...                                      ...
# 57416     ZYYK       YKH        NaN                      122.3586, 40.542524
# 57417     ZYYY       NaN        NaN   123.49600219726562, 41.784400939941406
# 57418      NaN       NaN        NaN                        1.4825, 51.894444
# 57419      NaN       NaN        NaN  47.296388888900005, -11.584277777799999
# 57420     RJX7       NaN       RJX7                    130.270556, 30.784722
#
# [57421 rows x 12 columns]

# %%
# airport_codes[airport_codes['ident'] == 'KJAX']
# name municipality gps_code coordinates

# %%
df_merged = pd.merge(airports, airport_codes, how = 'left', left_on = 'Airport ID', right_on = 'ident')

# %%
df_merged['long'], df_merged['lat'] = df_merged['coordinates'].str.split(',', 1).str
# Out:
# <ipython-input-11-e3d884dec4d5>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df_merged['long'], df_merged['lat'] = df_merged['coordinates'].str.split(',', 1).str

# %%
df_merged
# Out:
#    Airport ID  Birdstrikes_N ident            type  \
# 0        KDFW            668  KDFW   large_airport
# 1        KSMF            551  KSMF   large_airport
# 2        KDEN            544  KDEN   large_airport
# 3        KPHL            408  KPHL   large_airport
# 4        KBNA            374  KBNA   large_airport
# 5        KMEM            367  KMEM   large_airport
# 6        KMCO            366  KMCO   large_airport
# 7        KMCI            343  KMCI   large_airport
# 8        KBWI            328  KBWI   large_airport
# 9        KHOU            293  KHOU   large_airport
# 10       KSTL            289  KSTL   large_airport
# 11       KOMA            263  KOMA   large_airport
# 12       KRSW            263  KRSW   large_airport
# 13       KMDW            255  KMDW   large_airport
# 14       KAUS            254  KAUS   large_airport
# 15       KSLC            253  KSLC   large_airport
# 16       KDAL            251  KDAL   large_airport
# 17       KSFO            241  KSFO   large_airport
# 18       KORD            236  KORD   large_airport
# 19       KFLL            235  KFLL   large_airport
# 20       KJFK            232  KJFK   large_airport
# 21       KMIA            220  KMIA   large_airport
# 22       KEWR            217  KEWR   large_airport
# 23       KCLT            202  KCLT   large_airport
# 24       KBOS            200  KBOS   large_airport
# 25       KOAK            195  KOAK   large_airport
# 26       KSJC            190  KSJC   large_airport
# 27       KSDF            187  KSDF   large_airport
# 28       KMSP            186  KMSP   large_airport
# 29       KLGA            186  KLGA   large_airport
# 30       KIAD            185  KIAD   large_airport
# 31       KCVG            181  KCVG   large_airport
# 32       KPIT            180  KPIT   large_airport
# 33       KBUF            173  KBUF   large_airport
# 34       PHLI            172  PHLI  medium_airport
# 35       KLAX            167  KLAX   large_airport
# 36       KSAT            165  KSAT   large_airport
# 37       KMSY            162  KMSY   large_airport
# 38       KRDU            156  KRDU   large_airport
# 39       KMKE            155  KMKE   large_airport
# 40       KCLE            147  KCLE   large_airport
# 41       KSFB            145  KSFB   large_airport
# 42       PHTO            143  PHTO  medium_airport
# 43       KBHM            141  KBHM   large_airport
# 44       KATL            141  KATL   large_airport
# 45       PHNL            140  PHNL   large_airport
# 46       KIAH            139  KIAH   large_airport
# 47       KBDL            135  KBDL   large_airport
# 48       KIND            134  KIND   large_airport
# 49       KPHX            128  KPHX   large_airport
# 50       KTPA            127  KTPA   large_airport
# 51       KJAX            126  KJAX   large_airport
# 52       KPDX            126  KPDX   large_airport
# 53       KMDT            117  KMDT  medium_airport
# 54       KONT            105  KONT   large_airport
#
#                                                  name  elevation_ft continent  \
# 0             Dallas Fort Worth International Airport         607.0       NaN
# 1                    Sacramento International Airport          27.0       NaN
# 2                        Denver International Airport        5431.0       NaN
# 3                  Philadelphia International Airport          36.0       NaN
# 4                     Nashville International Airport         599.0       NaN
# 5                       Memphis International Airport         341.0       NaN
# 6                       Orlando International Airport          96.0       NaN
# 7                   Kansas City International Airport        1026.0       NaN
# 8   Baltimore/Washington International Thurgood Ma...         146.0       NaN
# 9                             William P Hobby Airport          46.0       NaN
# 10             St Louis Lambert International Airport         618.0       NaN
# 11                                    Eppley Airfield         984.0       NaN
# 12            Southwest Florida International Airport          30.0       NaN
# 13               Chicago Midway International Airport         620.0       NaN
# 14             Austin Bergstrom International Airport         542.0       NaN
# 15               Salt Lake City International Airport        4227.0       NaN
# 16                                  Dallas Love Field         487.0       NaN
# 17                San Francisco International Airport          13.0       NaN
# 18               Chicago O'Hare International Airport         672.0       NaN
# 19    Fort Lauderdale Hollywood International Airport           9.0       NaN
# 20               John F Kennedy International Airport          13.0       NaN
# 21                        Miami International Airport           8.0       NaN
# 22               Newark Liberty International Airport          18.0       NaN
# 23            Charlotte Douglas International Airport         748.0       NaN
# 24  General Edward Lawrence Logan International Ai...          20.0       NaN
# 25         Metropolitan Oakland International Airport           9.0       NaN
# 26    Norman Y. Mineta San Jose International Airport          62.0       NaN
# 27      Louisville Muhammad Ali International Airport         501.0       NaN
# 28  Minneapolis-St Paul International/Wold-Chamber...         841.0       NaN
# 29                                 La Guardia Airport          21.0       NaN
# 30            Washington Dulles International Airport         312.0       NaN
# 31  Cincinnati Northern Kentucky International Air...         896.0       NaN
# 32                   Pittsburgh International Airport        1203.0       NaN
# 33              Buffalo Niagara International Airport         728.0       NaN
# 34                                      Lihue Airport         153.0       NaN
# 35                  Los Angeles International Airport         125.0       NaN
# 36                  San Antonio International Airport         809.0       NaN
# 37  Louis Armstrong New Orleans International Airport           4.0       NaN
# 38               Raleigh Durham International Airport         435.0       NaN
# 39             General Mitchell International Airport         723.0       NaN
# 40            Cleveland Hopkins International Airport         791.0       NaN
# 41              Orlando Sanford International Airport          55.0       NaN
# 42                         Hilo International Airport          38.0       NaN
# 43     Birmingham-Shuttlesworth International Airport         650.0       NaN
# 44   Hartsfield Jackson Atlanta International Airport        1026.0       NaN
# 45              Daniel K Inouye International Airport          13.0       NaN
# 46       George Bush Intercontinental Houston Airport          97.0       NaN
# 47                      Bradley International Airport         173.0       NaN
# 48                 Indianapolis International Airport         797.0       NaN
# 49           Phoenix Sky Harbor International Airport        1135.0       NaN
# 50                        Tampa International Airport          26.0       NaN
# 51                 Jacksonville International Airport          30.0       NaN
# 52                     Portland International Airport          31.0       NaN
# 53                   Harrisburg International Airport         310.0       NaN
# 54                      Ontario International Airport         944.0       NaN
#
#    iso_country iso_region            municipality gps_code iata_code  \
# 0           US      US-TX       Dallas-Fort Worth     KDFW       DFW
# 1           US      US-CA              Sacramento     KSMF       SMF
# 2           US      US-CO                  Denver     KDEN       DEN
# 3           US      US-PA            Philadelphia     KPHL       PHL
# 4           US      US-TN               Nashville     KBNA       BNA
# 5           US      US-TN                 Memphis     KMEM       MEM
# 6           US      US-FL                 Orlando     KMCO       MCO
# 7           US      US-MO             Kansas City     KMCI       MCI
# 8           US      US-MD               Baltimore     KBWI       BWI
# 9           US      US-TX                 Houston     KHOU       HOU
# 10          US      US-MO                St Louis     KSTL       STL
# 11          US      US-NE                   Omaha     KOMA       OMA
# 12          US      US-FL              Fort Myers     KRSW       RSW
# 13          US      US-IL                 Chicago     KMDW       MDW
# 14          US      US-TX                  Austin     KAUS       AUS
# 15          US      US-UT          Salt Lake City     KSLC       SLC
# 16          US      US-TX                  Dallas     KDAL       DAL
# 17          US      US-CA           San Francisco     KSFO       SFO
# 18          US      US-IL                 Chicago     KORD       ORD
# 19          US      US-FL         Fort Lauderdale     KFLL       FLL
# 20          US      US-NY                New York     KJFK       JFK
# 21          US      US-FL                   Miami     KMIA       MIA
# 22          US      US-NJ                  Newark     KEWR       EWR
# 23          US      US-NC               Charlotte     KCLT       CLT
# 24          US      US-MA                  Boston     KBOS       BOS
# 25          US      US-CA                 Oakland     KOAK       OAK
# 26          US      US-CA                San Jose     KSJC       SJC
# 27          US      US-KY              Louisville     KSDF       SDF
# 28          US      US-MN             Minneapolis     KMSP       MSP
# 29          US      US-NY                New York     KLGA       LGA
# 30          US      US-DC              Washington     KIAD       IAD
# 31          US      US-KY  Cincinnati / Covington     KCVG       CVG
# 32          US      US-PA              Pittsburgh     KPIT       PIT
# 33          US      US-NY                 Buffalo     KBUF       BUF
# 34          US      US-HI                   Lihue     PHLI       LIH
# 35          US      US-CA             Los Angeles     KLAX       LAX
# 36          US      US-TX             San Antonio     KSAT       SAT
# 37          US      US-LA             New Orleans     KMSY       MSY
# 38          US      US-NC          Raleigh/Durham     KRDU       RDU
# 39          US      US-WI               Milwaukee     KMKE       MKE
# 40          US      US-OH               Cleveland     KCLE       CLE
# 41          US      US-FL                 Orlando     KSFB       SFB
# 42          US      US-HI                    Hilo     PHTO       ITO
# 43          US      US-AL              Birmingham     KBHM       BHM
# 44          US      US-GA                 Atlanta     KATL       ATL
# 45          US      US-HI                Honolulu     PHNL       HNL
# 46          US      US-TX                 Houston     KIAH       IAH
# 47          US      US-CT                Hartford     KBDL       BDL
# 48          US      US-IN            Indianapolis     KIND       IND
# 49          US      US-AZ                 Phoenix     KPHX       PHX
# 50          US      US-FL                   Tampa     KTPA       TPA
# 51          US      US-FL            Jacksonville     KJAX       JAX
# 52          US      US-OR                Portland     KPDX       PDX
# 53          US      US-PA              Harrisburg     KMDT       MDT
# 54          US      US-CA                 Ontario     KONT       ONT
#
#    local_code                              coordinates                 long  \
# 0         DFW                    -97.038002, 32.896801           -97.038002
# 1         SMF   -121.59100341796875, 38.69540023803711  -121.59100341796875
# 2         DEN          -104.672996521, 39.861698150635       -104.672996521
# 3         PHL    -75.24109649658203, 39.87189865112305   -75.24109649658203
# 4         BNA      -86.6781997680664, 36.1245002746582    -86.6781997680664
# 5         MEM    -89.97669982910156, 35.04240036010742   -89.97669982910156
# 6         MCO   -81.30899810791016, 28.429399490356445   -81.30899810791016
# 7         MCI                      -94.713898, 39.2976           -94.713898
# 8         BWI                      -76.668297, 39.1754           -76.668297
# 9         HOU                -95.27890015, 29.64539909         -95.27890015
# 10        STL                    -90.370003, 38.748697           -90.370003
# 11        OMA                      -95.894096, 41.3032           -95.894096
# 12        RSW    -81.75520324707031, 26.53619956970215   -81.75520324707031
# 13        MDW                    -87.752403, 41.785999           -87.752403
# 14        AUS    -97.6698989868164, 30.194499969482422    -97.6698989868164
# 15        SLC   -111.97799682617188, 40.78839874267578  -111.97799682617188
# 16        DAL                    -96.851799, 32.847099           -96.851799
# 17        SFO              -122.375, 37.61899948120117             -122.375
# 18        ORD                        -87.9048, 41.9786             -87.9048
# 19        FLL                    -80.152702, 26.072599           -80.152702
# 20        JFK                      -73.7789, 40.639801             -73.7789
# 21        MIA    -80.29060363769531, 25.79319953918457   -80.29060363769531
# 22        EWR     -74.168701171875, 40.692501068115234     -74.168701171875
# 23        CLT     -80.94309997558594, 35.2140007019043   -80.94309997558594
# 24        BOS                -71.00520325, 42.36429977         -71.00520325
# 25        OAK                   -122.221001, 37.721298          -122.221001
# 26        SJC                   -121.929001, 37.362598          -121.929001
# 27        SDF                         -85.736, 38.1744              -85.736
# 28        MSP                       -93.221802, 44.882           -93.221802
# 29        LGA                    -73.872597, 40.777199           -73.872597
# 30        IAD                -77.45580292, 38.94449997         -77.45580292
# 31        CVG                    -84.667801, 39.048801           -84.667801
# 32        PIT                -80.23290253, 40.49150085         -80.23290253
# 33        BUF                -78.73220062, 42.94049835         -78.73220062
# 34        LIH   -159.33900451660156, 21.97599983215332  -159.33900451660156
# 35        LAX                   -118.407997, 33.942501          -118.407997
# 36        SAT                    -98.469803, 29.533701           -98.469803
# 37        MSY    -90.25800323486328, 29.99340057373047   -90.25800323486328
# 38        RDU    -78.7874984741211, 35.877601623535156    -78.7874984741211
# 39        MKE   -87.89659881591797, 42.947200775146484   -87.89659881591797
# 40        CLE            -81.8498001099, 41.4117012024       -81.8498001099
# 41        SFB   -81.23750305175781, 28.777599334716797   -81.23750305175781
# 42        ITO  -155.04800415039062, 19.721399307250977  -155.04800415039062
# 43        BHM                -86.75350189, 33.56290054         -86.75350189
# 44        ATL                      -84.428101, 33.6367           -84.428101
# 45        HNL                    -157.924228, 21.32062          -157.924228
# 46        IAH   -95.34140014648438, 29.984399795532227   -95.34140014648438
# 47        BDL        -72.68319702149999, 41.9388999939   -72.68319702149999
# 48        IND                      -86.294403, 39.7173           -86.294403
# 49        PHX   -112.01200103759766, 33.43429946899414  -112.01200103759766
# 50        TPA        -82.533203125, 27.975500106811523        -82.533203125
# 51        JAX    -81.68789672851562, 30.49410057067871   -81.68789672851562
# 52        PDX                -122.5979996, 45.58869934         -122.5979996
# 53        MDT            -76.7633972168, 40.1935005188       -76.7633972168
# 54        ONT  -117.60099792480469, 34.055999755859375  -117.60099792480469
#
#                     lat
# 0             32.896801
# 1     38.69540023803711
# 2       39.861698150635
# 3     39.87189865112305
# 4      36.1245002746582
# 5     35.04240036010742
# 6    28.429399490356445
# 7               39.2976
# 8               39.1754
# 9           29.64539909
# 10            38.748697
# 11              41.3032
# 12    26.53619956970215
# 13            41.785999
# 14   30.194499969482422
# 15    40.78839874267578
# 16            32.847099
# 17    37.61899948120117
# 18              41.9786
# 19            26.072599
# 20            40.639801
# 21    25.79319953918457
# 22   40.692501068115234
# 23     35.2140007019043
# 24          42.36429977
# 25            37.721298
# 26            37.362598
# 27              38.1744
# 28               44.882
# 29            40.777199
# 30          38.94449997
# 31            39.048801
# 32          40.49150085
# 33          42.94049835
# 34    21.97599983215332
# 35            33.942501
# 36            29.533701
# 37    29.99340057373047
# 38   35.877601623535156
# 39   42.947200775146484
# 40        41.4117012024
# 41   28.777599334716797
# 42   19.721399307250977
# 43          33.56290054
# 44              33.6367
# 45             21.32062
# 46   29.984399795532227
# 47        41.9388999939
# 48              39.7173
# 49    33.43429946899414
# 50   27.975500106811523
# 51    30.49410057067871
# 52          45.58869934
# 53        40.1935005188
# 54   34.055999755859375

# %%
column_names = ["lat_", "long_", "zipcode"]

df_w_zip = pd.DataFrame(columns = column_names)

# %%
Token = '546a860b4a7a4d0697f2fe7f66f1e7e5'

# %%
# initially, list was used to store zip codes, then switched to df
# zip_codes_list = []

# %%
for index, row in df_merged.iterrows():
    #make the api call
    response = requests.get('https://api.bigdatacloud.net/data/reverse-geocode?latitude='+row.lat+'&longitude='+row.long+'&localityLanguage=en&key='+Token)  
    #load the api response as a json
    res_json = json.loads(response.text)
    new_row = {'lat_':row.lat, 'long_': row.long, 'zipcode': res_json['postcode']}
    df_w_zip = df_w_zip.append(new_row, ignore_index=True)

# %%
df_w_zip.head()
# Out:
#                  lat_                long_ zipcode
# 0           32.896801           -97.038002   76051
# 1   38.69540023803711  -121.59100341796875   95837
# 2     39.861698150635       -104.672996521   80249
# 3   39.87189865112305   -75.24109649658203   19113
# 4    36.1245002746582    -86.6781997680664   37214

# %%
# this csv was not helpful
# zip_codes = pd.read_csv('us-zip-code-latitude-and-longitude.csv', sep=';')

# %%
# 1) we should connect df_w_zip to df_merged;
df_w_coord = pd.merge(df_merged, df_w_zip, how = 'left', left_on = ["lat","long"], right_on = ["lat_", "long_"])
df_w_coord.drop(['local_code','lat_','long_'], axis = 1, inplace = True)

# %%
df_w_coord.head()
# Out:
#   Airport ID  Birdstrikes_N ident           type  \
# 0       KDFW            668  KDFW  large_airport
# 1       KSMF            551  KSMF  large_airport
# 2       KDEN            544  KDEN  large_airport
# 3       KPHL            408  KPHL  large_airport
# 4       KBNA            374  KBNA  large_airport
#
#                                       name  elevation_ft continent  \
# 0  Dallas Fort Worth International Airport         607.0       NaN
# 1         Sacramento International Airport          27.0       NaN
# 2             Denver International Airport        5431.0       NaN
# 3       Philadelphia International Airport          36.0       NaN
# 4          Nashville International Airport         599.0       NaN
#
#   iso_country iso_region       municipality gps_code iata_code  \
# 0          US      US-TX  Dallas-Fort Worth     KDFW       DFW
# 1          US      US-CA         Sacramento     KSMF       SMF
# 2          US      US-CO             Denver     KDEN       DEN
# 3          US      US-PA       Philadelphia     KPHL       PHL
# 4          US      US-TN          Nashville     KBNA       BNA
#
#                               coordinates                 long  \
# 0                   -97.038002, 32.896801           -97.038002
# 1  -121.59100341796875, 38.69540023803711  -121.59100341796875
# 2         -104.672996521, 39.861698150635       -104.672996521
# 3   -75.24109649658203, 39.87189865112305   -75.24109649658203
# 4     -86.6781997680664, 36.1245002746582    -86.6781997680664
#
#                   lat zipcode
# 0           32.896801   76051
# 1   38.69540023803711   95837
# 2     39.861698150635   80249
# 3   39.87189865112305   19113
# 4    36.1245002746582   37214

# %%
start_date = pd.date_range(start="2015-01-01",end="2020-01-01", freq = 'AS')
end_date = pd.date_range(start="2015-12-31",end="2020-12-31", freq = 'A')

# %%
start_date = pd.Series(start_date.format(), name = "start_date")
end_date = pd.Series(end_date.format(), name = "end_date")

# %%
df_w_date = pd.concat([start_date, end_date], axis = 1)
df_w_date.head()
# Out:
#    start_date    end_date
# 0  2015-01-01  2015-12-31
# 1  2016-01-01  2016-12-31
# 2  2017-01-01  2017-12-31
# 3  2018-01-01  2018-12-31
# 4  2019-01-01  2019-12-31

# %%
column_names = ["date", "datatype", "station", "zipcode" "attributes","value"]

df_w_weather = pd.DataFrame(columns = column_names)

# %%
# 2) get weather data based on zip
#for index, row, date_index, date_row in zip(df_merged.iterrows(),df_w_date.iterrows()):
for index,row in df_w_zip.iterrows():
    for date_index,date_row in df_w_date.iterrows():
        #make the api call
        response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:'+row.zipcode+'&startdate='+date_row.start_date+'&enddate='+date_row.end_date, headers={'token':Token})
        res_json = json.loads(response.text)
        res_json = res_json['results']
        #new_row = {'date': res_json['date'], 'datatype': res_json['datatype'], 'station': res_json['station'], 'zipcode':row.zipcode, 'attributes': res_json['attributes'], 'value': res_json['value']}
        new_row = {'date': res_json[0]['date'], 'datatype': res_json[0][ 'datatype'], 'station': res_json[0]['station'], 'zipcode':row.zipcode, 'attributes': res_json[0]['attributes'], 'value': res_json[0]['value']}
        df_w_weather = df_w_weather.append(new_row, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-ebf8644b9c94> in <module>
#       4     for date_index,date_row in df_w_date.iterrows():
#       5         #make the api call
# ----> 6         response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:'+row.zipcode+'&startdate='+date_row.start_date+'&enddate='+date_row.end_date, headers={'token':Token})
#       7         res_json = json.loads(response.text)
#       8         res_json = res_json['results']
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
Token = 'pgiGvZTCXlwUolZMKeeMTjEnzJTFCPLW'
response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:28801&startdate=2015-01-01&enddate=2015-12-31', headers={'token':Token})
res_json = json.loads(response.text)
res_json = res_json['results']
res_json[1]['date']
# Out:
# '2015-01-01T00:00:00'

# %%
res_json[0]
# Out:
# {'date': '2015-01-01T00:00:00',
#  'datatype': 'PRCP',
#  'station': 'GHCND:US1NCBC0005',
#  'attributes': ',,N,',
#  'value': 0}

# %%
dates_temp = []
dates_prcp = []
temps = []
prcp = []

# 2) get weather data based on zip
#for index, row, date_index, date_row in zip(df_merged.iterrows(),df_w_date.iterrows()):
for index,row in df_w_zip.iterrows():
    for date_index,date_row in df_w_date.iterrows():
        #make the api call
        response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:'+row.zipcode+'&startdate='+date_row.start_date+'&enddate='+date_row.end_date, headers={'token':Token})
        res_json = json.loads(response.text)
        #get all items in the response which are average temperature readings
        avg_temps = [item for item in res_json['results'] if item['datatype']=='TAVG']
        #get the date field from all average temperature readings
        dates_temp += [item['date'] for item in avg_temps]
        #get the actual average temperature from all average temperature readings
        temps += [item['value'] for item in avg_temps]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-450ff5dbeadb> in <module>
#      12         res_json = json.loads(response.text)
#      13         #get all items in the response which are average temperature readings
# ---> 14         avg_temps = [item for item in res_json['results'] if item['datatype']=='TAVG']
#      15         #get the date field from all average temperature readings
#      16         dates_temp += [item['date'] for item in avg_temps]
#
# KeyError: 'results'

# %%
weather_stats = ['PRCP', 'SNOW', '']

# %%
#initialize lists to store data
dates_temp = []
dates_prcp = []
temps = []
prcp = []

#for each year from 2015-2019 ...
for year in range(2015, 2019):
    year = str(year)
    print('working on year '+year)
    
    #make the api call
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #load the api response as a json
    d = json.loads(r.text)
    if d == None:
        continue
    else:
        #get all items in the response which are average temperature readings
        avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']
        #get the date field from all average temperature readings
        dates_temp += [item['date'] for item in avg_temps]
        #get the actual average temperature from all average temperature readings
        temps += [item['value'] for item in avg_temps]
# Out:
# working on year 2015
# working on year 2016
# working on year 2017
# working on year 2018

# %%
df_temp = pd.DataFrame()

#populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0*1.8 + 32 for v in temps]

# %%
df_temp
# Out:
#            date  avgTemp
# 0    2015-01-01    46.58
# 1    2015-01-02    48.02
# 2    2015-01-03    49.82
# 3    2015-01-04    52.16
# 4    2015-01-05    58.64
# ...         ...      ...
# 1456 2018-12-27    55.76
# 1457 2018-12-28    54.50
# 1458 2018-12-29    51.62
# 1459 2018-12-30    51.98
# 1460 2018-12-31    54.86
#
# [1461 rows x 2 columns]
