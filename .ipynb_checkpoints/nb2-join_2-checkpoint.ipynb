# %%
import pandas as pd
import numpy as np

import requests
import json
from datetime import datetime

# %% [markdown]
# **Import df_cleaned.csv**

# %%
df_cleaned = pd.read_csv('df_cleaned.csv')

# %%
len(df_cleaned)
# Out:
# 11675

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0  Record ID  Incident Year  Incident Month  Incident Day  \
# 0      106753     300045           2010               1             1
# 1      106754     300390           2010               1             1
# 2      106764     300701           2010               1             2
# 3      106765     300186           2010               1             2
# 4      106769     301152           2010               1             2
#
#   Operator ID            Operator    Aircraft Aircraft Type Aircraft Make  \
# 0         BUS            BUSINESS       C-310             A           226
# 1         JBU     JETBLUE AIRWAYS       A-320             A           04A
# 2         SKW    SKYWEST AIRLINES  CRJ100/200             A           188
# 3         NWA  NORTHWEST AIRLINES        DC-9             A           583
# 4         JBU     JETBLUE AIRWAYS       A-320             A           04A
#
#    ...  Flight Phase Visibility Precipitation Height  Speed Distance  \
# 0  ...   TAKEOFF RUN        DAY          NONE    0.0   30.0      0.0
# 1  ...   TAKEOFF RUN        DAY          RAIN    0.0  120.0      0.0
# 2  ...  LANDING ROLL        DAY          NONE    0.0   80.0      0.0
# 3  ...   TAKEOFF RUN        DAY          NONE    0.0  140.0      0.0
# 4  ...      APPROACH        DAY          NONE   20.0  120.0      0.0
#
#   Species ID  Species Name  Species Quantity    Flight Impact
# 0        NE1          GULL                 1  ABORTED TAKEOFF
# 1        ZT3       GRACKLE                 1             NONE
# 2      YH004   HORNED LARK                 1             NONE
# 3        K33          HAWK                 1             NONE
# 4      YI010  TREE SWALLOW                 1             NONE
#
# [5 rows x 25 columns]

# %% [markdown]
# **Create birdstrike count for airports and save as csv**

# %%
airport_counts = df_cleaned.groupby('Airport ID').size().sort_values(ascending=False)
df_airports = pd.DataFrame({'Airport ID':airport_counts.index, 'Birdstrikes_N':airport_counts.values})

# %%
df_airports.head()
# Out:
#   Airport ID  Birdstrikes_N
# 0       KDFW            402
# 1       KSMF            337
# 2       KDEN            293
# 3       KPHL            286
# 4       KBNA            258

# %% [markdown]
# **Import airport_codes_csv (downloaded from internet)**

# %%
airport_codes = pd.read_csv('airport-codes_csv.csv')

# %%
airport_codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# 1       00AA                 -101.473911, 38.704022
# 2       00AK            -151.695999146, 59.94919968
# 3       00AL  -86.77030181884766, 34.86479949951172
# 4        NaN                    -91.254898, 35.6087

# %%
# airport_codes[airport_codes['ident'] == 'KJAX']
# name municipality gps_code coordinates

# %%
#df_merged = pd.merge(airports, airport_codes, how = 'left', left_on = 'Airport ID', right_on = 'ident')

# %%
#df_merged['long'], df_merged['lat'] = df_merged['coordinates'].str.split(',', 1).str

# %%
#len(df_merged)

# %%
#pd.set_option('display.max_rows', None)

# %%
len(airport_codes)
# Out:
# 57421

# %% [markdown]
# **Merging df_airports and airport_codes to get long/lat values for airport IDs that only our data has**

# %%
df_merged_4 = pd.merge(df_airports, airport_codes, how = 'inner', left_on = 'Airport ID', right_on = 'ident')

# %%
df_merged_4['long'], df_merged_4['lat'] = df_merged_4['coordinates'].str.split(',', 1).str
# Out:
# <ipython-input-17-dbca08aead81>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df_merged_4['long'], df_merged_4['lat'] = df_merged_4['coordinates'].str.split(',', 1).str

# %%
df_merged_4['lat'] = df_merged_4['lat'].astype(str)
df_merged_4['long'] = df_merged_4['long'].astype(str)

# %%
df_merged_4.head()
# Out:
#   Airport ID  Birdstrikes_N ident           type  \
# 0       KDFW            402  KDFW  large_airport
# 1       KSMF            337  KSMF  large_airport
# 2       KDEN            293  KDEN  large_airport
# 3       KPHL            286  KPHL  large_airport
# 4       KBNA            258  KBNA  large_airport
#
#                                       name  elevation_ft continent  \
# 0  Dallas Fort Worth International Airport         607.0       NaN
# 1         Sacramento International Airport          27.0       NaN
# 2             Denver International Airport        5431.0       NaN
# 3       Philadelphia International Airport          36.0       NaN
# 4          Nashville International Airport         599.0       NaN
#
#   iso_country iso_region       municipality gps_code iata_code local_code  \
# 0          US      US-TX  Dallas-Fort Worth     KDFW       DFW        DFW
# 1          US      US-CA         Sacramento     KSMF       SMF        SMF
# 2          US      US-CO             Denver     KDEN       DEN        DEN
# 3          US      US-PA       Philadelphia     KPHL       PHL        PHL
# 4          US      US-TN          Nashville     KBNA       BNA        BNA
#
#                               coordinates                 long  \
# 0                   -97.038002, 32.896801           -97.038002
# 1  -121.59100341796875, 38.69540023803711  -121.59100341796875
# 2         -104.672996521, 39.861698150635       -104.672996521
# 3   -75.24109649658203, 39.87189865112305   -75.24109649658203
# 4     -86.6781997680664, 36.1245002746582    -86.6781997680664
#
#                   lat
# 0           32.896801
# 1   38.69540023803711
# 2     39.861698150635
# 3   39.87189865112305
# 4    36.1245002746582

# %% [markdown]
# **Create empty zips with lat/long df**

# %%
column_names = ["lat_", "long_", "zipcode"]
df_w_zip = pd.DataFrame(columns = column_names)

# %% [markdown]
# **Import zipcodes via API**

# %%
Token = '546a860b4a7a4d0697f2fe7f66f1e7e5'

# %%
# initially, list was used to store zip codes, then switched to df
# zip_codes_list = []

# %%
for index, row in df_merged_4.iterrows():
    #make the api call
    response = requests.get('https://api.bigdatacloud.net/data/reverse-geocode?latitude='+row.lat+'&longitude='+row.long+'&localityLanguage=en&key='+Token)  
    #load the api response as a json
    res_json = json.loads(response.text)
    if res_json['postcode'] == None:
        continue
    else:
        new_row = {'lat_':row.lat, 'long_': row.long, 'zipcode': res_json['postcode']}
        # print(new_row)
        df_w_zip = df_w_zip.append(new_row, ignore_index=True)

# %%
len(df_w_zip)
# Out:
# 802

# %%
df_w_zip.head()
# Out:
#                  lat_                long_ zipcode
# 0           32.896801           -97.038002   76051
# 1   38.69540023803711  -121.59100341796875   95837
# 2     39.861698150635       -104.672996521   80249
# 3   39.87189865112305   -75.24109649658203   19113
# 4    36.1245002746582    -86.6781997680664   37214

# %%
# this csv was not helpful
# zip_codes = pd.read_csv('us-zip-code-latitude-and-longitude.csv', sep=';')

# %% [markdown]
# **Join all dates together into one column**

# %%
df_cleaned["incident_date"] = df_cleaned["Incident Year"].astype(str) + "-" + df_cleaned["Incident Month"].astype(str) + "-" + df_cleaned["Incident Day"].astype(str)
df_cleaned["incident_date"] = pd.to_datetime(df_cleaned['incident_date'], format= '%Y-%m-%d').astype(str)
# date_list = pd.DataFrame(df_cleaned['incident_date'])
# date_list['incident_date'] = date_list['incident_date'].astype(str)

# %%
len(df_cleaned)
# Out:
# 11675

# %%
#len(df_cleaned[df_cleaned['incident_date'].str.contains("2010")])

# %%
df_cleaned_coord = pd.merge(df_cleaned, df_merged_4, how = 'left', left_on = 'Airport ID', right_on = 'Airport ID')

# %%
df_cleaned_coord.head()
# Out:
#    Unnamed: 0  Record ID  Incident Year  Incident Month  Incident Day  \
# 0      106753     300045           2010               1             1
# 1      106754     300390           2010               1             1
# 2      106764     300701           2010               1             2
# 3      106765     300186           2010               1             2
# 4      106769     301152           2010               1             2
#
#   Operator ID            Operator    Aircraft Aircraft Type Aircraft Make  \
# 0         BUS            BUSINESS       C-310             A           226
# 1         JBU     JETBLUE AIRWAYS       A-320             A           04A
# 2         SKW    SKYWEST AIRLINES  CRJ100/200             A           188
# 3         NWA  NORTHWEST AIRLINES        DC-9             A           583
# 4         JBU     JETBLUE AIRWAYS       A-320             A           04A
#
#    ... continent iso_country iso_region    municipality gps_code iata_code  \
# 0  ...       NaN          US      US-FL   Pompano Beach     KPMP       PPM
# 1  ...       NaN          US      US-FL         Orlando     KMCO       MCO
# 2  ...       NaN          US      US-UT  Salt Lake City     KSLC       SLC
# 3  ...       NaN          US      US-MD       Baltimore     KBWI       BWI
# 4  ...       NaN          US      US-FL         Orlando     KMCO       MCO
#
#   local_code                             coordinates                 long  \
# 0        PMP       -80.111099243164, 26.247100830078     -80.111099243164
# 1        MCO  -81.30899810791016, 28.429399490356445   -81.30899810791016
# 2        SLC  -111.97799682617188, 40.78839874267578  -111.97799682617188
# 3        BWI                     -76.668297, 39.1754           -76.668297
# 4        MCO  -81.30899810791016, 28.429399490356445   -81.30899810791016
#
#                    lat
# 0      26.247100830078
# 1   28.429399490356445
# 2    40.78839874267578
# 3              39.1754
# 4   28.429399490356445
#
# [5 rows x 41 columns]

# %%
df_cleaned_coord = df_cleaned_coord.drop(columns=['continent','iso_country','iso_region','gps_code','iata_code','local_code'])

# %%
df_cleaned_coord.columns
# Out:
# Index(['Unnamed: 0', 'Record ID', 'Incident Year', 'Incident Month',
#        'Incident Day', 'Operator ID', 'Operator', 'Aircraft', 'Aircraft Type',
#        'Aircraft Make', 'Aircraft Model', 'Airport ID', 'Airport', 'State',
#        'FAA Region', 'Flight Phase', 'Visibility', 'Precipitation', 'Height',
#        'Speed', 'Distance', 'Species ID', 'Species Name', 'Species Quantity',
#        'Flight Impact', 'incident_date', 'Birdstrikes_N', 'ident', 'type',
#        'name', 'elevation_ft', 'municipality', 'coordinates', 'long', 'lat'],
#       dtype='object')

# %%
df_zip_date = pd.merge(df_cleaned_coord, df_w_zip, how = 'left', left_on = ['long', 'lat'], right_on = ['long_', 'lat_'])

# %%
df_zip_date.head()
# Out:
#    Unnamed: 0  Record ID  Incident Year  Incident Month  Incident Day  \
# 0      106753     300045           2010               1             1
# 1      106754     300390           2010               1             1
# 2      106764     300701           2010               1             2
# 3      106765     300186           2010               1             2
# 4      106769     301152           2010               1             2
#
#   Operator ID            Operator    Aircraft Aircraft Type Aircraft Make  \
# 0         BUS            BUSINESS       C-310             A           226
# 1         JBU     JETBLUE AIRWAYS       A-320             A           04A
# 2         SKW    SKYWEST AIRLINES  CRJ100/200             A           188
# 3         NWA  NORTHWEST AIRLINES        DC-9             A           583
# 4         JBU     JETBLUE AIRWAYS       A-320             A           04A
#
#    ...           type                                               name  \
# 0  ...  small_airport                              Pompano Beach Airpark
# 1  ...  large_airport                      Orlando International Airport
# 2  ...  large_airport               Salt Lake City International Airport
# 3  ...  large_airport  Baltimore/Washington International Thurgood Ma...
# 4  ...  large_airport                      Orlando International Airport
#
#   elevation_ft    municipality                             coordinates  \
# 0         19.0   Pompano Beach       -80.111099243164, 26.247100830078
# 1         96.0         Orlando  -81.30899810791016, 28.429399490356445
# 2       4227.0  Salt Lake City  -111.97799682617188, 40.78839874267578
# 3        146.0       Baltimore                     -76.668297, 39.1754
# 4         96.0         Orlando  -81.30899810791016, 28.429399490356445
#
#                   long                  lat                 lat_  \
# 0     -80.111099243164      26.247100830078      26.247100830078
# 1   -81.30899810791016   28.429399490356445   28.429399490356445
# 2  -111.97799682617188    40.78839874267578    40.78839874267578
# 3           -76.668297              39.1754              39.1754
# 4   -81.30899810791016   28.429399490356445   28.429399490356445
#
#                  long_  zipcode
# 0     -80.111099243164    33060
# 1   -81.30899810791016    32827
# 2  -111.97799682617188    84116
# 3           -76.668297    21240
# 4   -81.30899810791016    32827
#
# [5 rows x 38 columns]

# %%
df_zip_date['zipcode'].isna().sum()
# Out:
# 73

# %%
df_zip_date = df_zip_date[df_zip_date["zipcode"] != ""]

# %%
len(df_zip_date)
# Out:
# 11597

# %%
df_zip_date.columns
# Out:
# Index(['Unnamed: 0', 'Record ID', 'Incident Year', 'Incident Month',
#        'Incident Day', 'Operator ID', 'Operator', 'Aircraft', 'Aircraft Type',
#        'Aircraft Make', 'Aircraft Model', 'Airport ID', 'Airport', 'State',
#        'FAA Region', 'Flight Phase', 'Visibility', 'Precipitation', 'Height',
#        'Speed', 'Distance', 'Species ID', 'Species Name', 'Species Quantity',
#        'Flight Impact', 'incident_date', 'Birdstrikes_N', 'ident', 'type',
#        'name', 'elevation_ft', 'municipality', 'coordinates', 'long', 'lat',
#        'lat_', 'long_', 'zipcode'],
#       dtype='object')

# %%
df_zip_date_2010 = df_zip_date[df_zip_date['incident_date'].str.contains("2010")]

# %%
df_zip_date_2010['zipcode'] = df_zip_date_2010['zipcode'].astype(str)
# Out:
# <ipython-input-41-0b76fc991acd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_zip_date_2010['zipcode'] = df_zip_date_2010['zipcode'].astype(str)

# %%
column_names = ["date", "station", "zipcode", "value"]

df_w_weather = pd.DataFrame(columns = column_names)

# %%
# Abduvosids
Token_w = 'EHZroSHTsmfKuOMeOWRkrDpMPWoZTXmb' 

#Fasihs
Token_f = 'pgiGvZTCXlwUolZMKeeMTjEnzJTFCPLW'

# %%
for index,row in df_zip_date_2010.iterrows():
    response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:'+row.zipcode+'&datatypeid=TOBS&startdate='+row.incident_date+'&enddate='+row.incident_date, 
                             headers={'token':Token_w})
    res_json = json.loads(response.text)
    if res_json != {}:
        new_row = {'date': row.incident_date, 'station': res_json['results'][0]['station'], 'zipcode': row.zipcode, 'value': res_json['results'][0]['value']}
        df_w_weather = df_w_weather.append(new_row, ignore_index=True)
        print(new_row)
# Out:
# {'date': '2010-01-07', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 50}
# {'date': '2010-01-10', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': -39}
# {'date': '2010-01-12', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': -6}
# {'date': '2010-01-16', 'station': 'GHCND:USC00502587', 'zipcode': '99685', 'value': 28}
# {'date': '2010-01-17', 'station': 'GHCND:USC00046572', 'zipcode': '93030', 'value': 117}
# {'date': '2010-01-19', 'station': 'GHCND:USC00500275', 'zipcode': '99502', 'value': -78}
# {'date': '2010-01-19', 'station': 'GHCND:USC00245740', 'zipcode': '59808', 'value': -6}
# {'date': '2010-01-22', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 100}
# {'date': '2010-01-28', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 133}
# {'date': '2010-01-29', 'station': 'GHCND:USC00142980', 'zipcode': '67846', 'value': -94}
# {'date': '2010-01-30', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 206}
# {'date': '2010-02-04', 'station': 'GHCND:USC00413943', 'zipcode': '78550', 'value': 167}
# {'date': '2010-02-15', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 106}
# {'date': '2010-02-16', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 89}
# {'date': '2010-02-26', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 139}
# {'date': '2010-03-01', 'station': 'GHCND:USC00454769', 'zipcode': '98626', 'value': 139}
# {'date': '2010-03-02', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 78}
# {'date': '2010-03-03', 'station': 'GHCND:USC00141699', 'zipcode': '67701', 'value': -22}
# {'date': '2010-03-03', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 117}
# {'date': '2010-03-05', 'station': 'GHCND:USC00088942', 'zipcode': '32780', 'value': 44}
# {'date': '2010-03-06', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 72}
# {'date': '2010-03-09', 'station': 'GHCND:USC00183353', 'zipcode': '21701', 'value': -6}
# {'date': '2010-03-10', 'station': 'GHCND:USC00454769', 'zipcode': '98626', 'value': 94}
# {'date': '2010-03-10', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 144}
# {'date': '2010-03-12', 'station': 'GHCND:USC00412011', 'zipcode': '78406', 'value': 144}
# {'date': '2010-03-16', 'station': 'GHCND:USC00415891', 'zipcode': '79706', 'value': 128}
# {'date': '2010-03-25', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 172}
# {'date': '2010-03-27', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'value': -150}
# {'date': '2010-04-05', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 200}
# {'date': '2010-04-07', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 222}
# {'date': '2010-04-09', 'station': 'GHCND:USC00503605', 'zipcode': '99835', 'value': 33}
# {'date': '2010-04-09', 'station': 'GHCND:USC00158555', 'zipcode': '42086', 'value': 94}
# {'date': '2010-04-09', 'station': 'GHCND:USC00063207', 'zipcode': '06340', 'value': 72}
# {'date': '2010-04-10', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 133}
# {'date': '2010-04-10', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 106}
# {'date': '2010-04-11', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 89}
# {'date': '2010-04-11', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 233}
# {'date': '2010-04-13', 'station': 'GHCND:USC00168923', 'zipcode': '71282', 'value': 156}
# {'date': '2010-04-16', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'value': 239}
# {'date': '2010-04-19', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 106}
# {'date': '2010-04-20', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 111}
# {'date': '2010-04-20', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 111}
# {'date': '2010-04-21', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 206}
# {'date': '2010-04-21', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 144}
# {'date': '2010-04-21', 'station': 'GHCND:USC00319100', 'zipcode': '27889', 'value': 133}
# {'date': '2010-04-22', 'station': 'GHCND:USC00111160', 'zipcode': '62206', 'value': 139}
# {'date': '2010-04-26', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 144}
# {'date': '2010-04-27', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 89}
# {'date': '2010-04-28', 'station': 'GHCND:USC00282805', 'zipcode': '08234', 'value': 61}
# {'date': '2010-04-28', 'station': 'GHCND:USC00478937', 'zipcode': '53188', 'value': 11}
# {'date': '2010-04-28', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 6}
# {'date': '2010-04-29', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 167}
# {'date': '2010-04-29', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'value': 256}
# {'date': '2010-04-30', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 189}
# {'date': '2010-05-03', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 122}
# {'date': '2010-05-03', 'station': 'GHCND:USC00262570', 'zipcode': '89801', 'value': 50}
# {'date': '2010-05-06', 'station': 'GHCND:USC00473268', 'zipcode': '54313', 'value': 72}
# {'date': '2010-05-07', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 239}
# {'date': '2010-05-07', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 117}
# {'date': '2010-05-09', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 83}
# {'date': '2010-05-11', 'station': 'GHCND:USC00148847', 'zipcode': '67209', 'value': 178}
# {'date': '2010-05-12', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 233}
# {'date': '2010-05-12', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'value': 89}
# {'date': '2010-05-12', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 233}
# {'date': '2010-05-16', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'value': 83}
# {'date': '2010-05-18', 'station': 'GHCND:USC00478919', 'zipcode': '53094', 'value': 100}
# {'date': '2010-05-18', 'station': 'GHCND:USC00504812', 'zipcode': '99615', 'value': 78}
# {'date': '2010-05-19', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 217}
# {'date': '2010-05-24', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 233}
# {'date': '2010-05-24', 'station': 'GHCND:USC00421259', 'zipcode': '84721', 'value': 6}
# {'date': '2010-05-24', 'station': 'GHCND:USC00111160', 'zipcode': '62206', 'value': 244}
# {'date': '2010-05-26', 'station': 'GHCND:USC00412793', 'zipcode': '79925', 'value': 267}
# {'date': '2010-05-28', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'value': 300}
# {'date': '2010-05-28', 'station': 'GHCND:USS0010D10S', 'zipcode': '59714', 'value': 20}
# {'date': '2010-06-01', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 94}
# {'date': '2010-06-01', 'station': 'GHCND:USC00504812', 'zipcode': '99615', 'value': 83}
# {'date': '2010-06-03', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 150}
# {'date': '2010-06-03', 'station': 'GHCND:USC00026796', 'zipcode': '86301', 'value': 150}
# {'date': '2010-06-03', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 228}
# {'date': '2010-06-10', 'station': 'GHCND:USC00456789', 'zipcode': '99163', 'value': 122}
# {'date': '2010-06-10', 'station': 'GHCND:USC00183353', 'zipcode': '21701', 'value': 200}
# {'date': '2010-06-11', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 156}
# {'date': '2010-06-13', 'station': 'GHCND:USC00054254', 'zipcode': '81137', 'value': 78}
# {'date': '2010-06-13', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'value': 89}
# {'date': '2010-06-14', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 161}
# {'date': '2010-06-18', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 106}
# {'date': '2010-06-20', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 206}
# {'date': '2010-06-23', 'station': 'GHCND:USC00010425', 'zipcode': '36830', 'value': 244}
# {'date': '2010-06-24', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 150}
# {'date': '2010-06-25', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 261}
# {'date': '2010-06-26', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 250}
# {'date': '2010-06-26', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 272}
# {'date': '2010-07-01', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 239}
# {'date': '2010-07-04', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 278}
# {'date': '2010-07-05', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 256}
# {'date': '2010-07-07', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 211}
# {'date': '2010-07-07', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 250}
# {'date': '2010-07-09', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 239}
# {'date': '2010-07-09', 'station': 'GHCND:USC00504812', 'zipcode': '99615', 'value': 94}
# {'date': '2010-07-10', 'station': 'GHCND:USC00415891', 'zipcode': '79706', 'value': 294}
# {'date': '2010-07-14', 'station': 'GHCND:USC00482375', 'zipcode': '83001', 'value': 178}
# {'date': '2010-07-14', 'station': 'GHCND:USC00391076', 'zipcode': '57006', 'value': 256}
# {'date': '2010-07-15', 'station': 'GHCND:USC00256075', 'zipcode': '69101', 'value': 150}
# {'date': '2010-07-15', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 228}
# {'date': '2010-07-16', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 244}
# {'date': '2010-07-16', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 267}
# {'date': '2010-07-17', 'station': 'GHCND:USC00143527', 'zipcode': '67601', 'value': 278}
# {'date': '2010-07-18', 'station': 'GHCND:USC00311677', 'zipcode': '27516', 'value': 222}
# {'date': '2010-07-19', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 89}
# {'date': '2010-07-19', 'station': 'GHCND:USC00254335', 'zipcode': '68847', 'value': 222}
# {'date': '2010-07-20', 'station': 'GHCND:USC00480552', 'zipcode': '82604', 'value': 94}
# {'date': '2010-07-20', 'station': 'GHCND:USC00332791', 'zipcode': '45840', 'value': 233}
# {'date': '2010-07-21', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 278}
# {'date': '2010-07-22', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 272}
# {'date': '2010-07-22', 'station': 'GHCND:USC00413943', 'zipcode': '78550', 'value': 244}
# {'date': '2010-07-22', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 283}
# {'date': '2010-07-22', 'station': 'GHCND:USC00456789', 'zipcode': '99163', 'value': 211}
# {'date': '2010-07-23', 'station': 'GHCND:USC00462920', 'zipcode': '26554', 'value': 239}
# {'date': '2010-07-23', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 156}
# {'date': '2010-07-24', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 272}
# {'date': '2010-07-24', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 150}
# {'date': '2010-07-26', 'station': 'GHCND:USC00055236', 'zipcode': '80538', 'value': 144}
# {'date': '2010-07-27', 'station': 'GHCND:USC00082150', 'zipcode': '32114', 'value': 278}
# {'date': '2010-07-28', 'station': 'GHCND:USC00142980', 'zipcode': '67846', 'value': 194}
# {'date': '2010-07-30', 'station': 'GHCND:USC00304174', 'zipcode': '14850', 'value': 122}
# {'date': '2010-07-30', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 267}
# {'date': '2010-07-31', 'station': 'GHCND:USC00464397', 'zipcode': '25704', 'value': 206}
# {'date': '2010-07-31', 'station': 'GHCND:USC00457941', 'zipcode': '99224', 'value': 111}
# {'date': '2010-07-31', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 228}
# {'date': '2010-08-01', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 233}
# {'date': '2010-08-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 261}
# {'date': '2010-08-03', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 267}
# {'date': '2010-08-04', 'station': 'GHCND:USC00210075', 'zipcode': '56007', 'value': 228}
# {'date': '2010-08-04', 'station': 'GHCND:USC00131319', 'zipcode': '52404', 'value': 267}
# {'date': '2010-08-04', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 283}
# {'date': '2010-08-05', 'station': 'GHCND:USC00165296', 'zipcode': '70510', 'value': 278}
# {'date': '2010-08-05', 'station': 'GHCND:USC00082150', 'zipcode': '32114', 'value': 261}
# {'date': '2010-08-08', 'station': 'GHCND:USC00500310', 'zipcode': '99835', 'value': 117}
# {'date': '2010-08-09', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 200}
# {'date': '2010-08-09', 'station': 'GHCND:USC00340312', 'zipcode': '73401', 'value': 283}
# {'date': '2010-08-10', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 283}
# {'date': '2010-08-12', 'station': 'GHCND:USC00063207', 'zipcode': '06340', 'value': 194}
# {'date': '2010-08-16', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 211}
# {'date': '2010-08-16', 'station': 'GHCND:USC00247560', 'zipcode': '59270', 'value': 244}
# {'date': '2010-08-18', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 144}
# {'date': '2010-08-18', 'station': 'GHCND:USC00092159', 'zipcode': '31909', 'value': 239}
# {'date': '2010-08-19', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 261}
# {'date': '2010-08-20', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 261}
# {'date': '2010-08-20', 'station': 'GHCND:USC00428771', 'zipcode': '84074', 'value': 306}
# {'date': '2010-08-20', 'station': 'GHCND:USC00415701', 'zipcode': '78503', 'value': 272}
# {'date': '2010-08-22', 'station': 'GHCND:USC00082150', 'zipcode': '32114', 'value': 267}
# {'date': '2010-08-23', 'station': 'GHCND:USC00117077', 'zipcode': '62305', 'value': 200}
# {'date': '2010-08-23', 'station': 'GHCND:USC00514561', 'zipcode': '96754', 'value': 261}
# {'date': '2010-08-25', 'station': 'GHCND:USC00412011', 'zipcode': '78406', 'value': 261}
# {'date': '2010-08-26', 'station': 'GHCND:USC00144559', 'zipcode': '66044', 'value': 161}
# {'date': '2010-08-26', 'station': 'GHCND:USC00203858', 'zipcode': '49423', 'value': 144}
# {'date': '2010-08-27', 'station': 'GHCND:USC00243753', 'zipcode': '59404', 'value': 122}
# {'date': '2010-08-27', 'station': 'GHCND:USC00063207', 'zipcode': '06340', 'value': 161}
# {'date': '2010-08-28', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 217}
# {'date': '2010-08-30', 'station': 'GHCND:USC00500275', 'zipcode': '99502', 'value': 94}
# {'date': '2010-08-31', 'station': 'GHCND:VQC00670480', 'zipcode': '00850', 'value': 294}
# {'date': '2010-08-31', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 267}
# {'date': '2010-09-01', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 239}
# {'date': '2010-09-02', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 211}
# {'date': '2010-09-03', 'station': 'GHCND:USC00172623', 'zipcode': '04605', 'value': 200}
# {'date': '2010-09-03', 'station': 'GHCND:USC00228374', 'zipcode': '39759', 'value': 233}
# {'date': '2010-09-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 139}
# {'date': '2010-09-03', 'station': 'GHCND:USC00415060', 'zipcode': '78041', 'value': 250}
# {'date': '2010-09-03', 'station': 'GHCND:USC00131319', 'zipcode': '52404', 'value': 183}
# {'date': '2010-09-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 139}
# {'date': '2010-09-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 139}
# {'date': '2010-09-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 139}
# {'date': '2010-09-06', 'station': 'GHCND:USC00415618', 'zipcode': '75672', 'value': 211}
# {'date': '2010-09-07', 'station': 'GHCND:USC00481676', 'zipcode': '82001', 'value': 144}
# {'date': '2010-09-10', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 256}
# {'date': '2010-09-10', 'station': 'GHCND:USC00243110', 'zipcode': '59501', 'value': 100}
# {'date': '2010-09-11', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'value': 283}
# {'date': '2010-09-12', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 256}
# {'date': '2010-09-12', 'station': 'GHCND:USC00419417', 'zipcode': '76708', 'value': 244}
# {'date': '2010-09-14', 'station': 'GHCND:USC00412011', 'zipcode': '78406', 'value': 278}
# {'date': '2010-09-14', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 250}
# {'date': '2010-09-15', 'station': 'GHCND:USC00334874', 'zipcode': '44903', 'value': 189}
# {'date': '2010-09-15', 'station': 'GHCND:USC00243753', 'zipcode': '59404', 'value': 144}
# {'date': '2010-09-15', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 222}
# {'date': '2010-09-16', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 133}
# {'date': '2010-09-16', 'station': 'GHCND:USC00334874', 'zipcode': '44903', 'value': 139}
# {'date': '2010-09-16', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 239}
# {'date': '2010-09-17', 'station': 'GHCND:USC00221880', 'zipcode': '39701', 'value': 250}
# {'date': '2010-09-20', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 183}
# {'date': '2010-09-21', 'station': 'GHCND:USC00026796', 'zipcode': '86301', 'value': 128}
# {'date': '2010-09-22', 'station': 'GHCND:USC00143218', 'zipcode': '67530', 'value': 300}
# {'date': '2010-09-23', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 250}
# {'date': '2010-09-23', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 250}
# {'date': '2010-09-23', 'station': 'GHCND:USC00082418', 'zipcode': '33040', 'value': 272}
# {'date': '2010-09-24', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 144}
# {'date': '2010-09-24', 'station': 'GHCND:USC00415060', 'zipcode': '78041', 'value': 261}
# {'date': '2010-09-25', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 122}
# {'date': '2010-09-25', 'station': 'GHCND:USC00415701', 'zipcode': '78503', 'value': 206}
# {'date': '2010-09-26', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 122}
# {'date': '2010-09-29', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 144}
# {'date': '2010-10-01', 'station': 'GHCND:USC00386153', 'zipcode': '29577', 'value': 178}
# {'date': '2010-10-01', 'station': 'GHCND:USC00041967', 'zipcode': '94520', 'value': 267}
# {'date': '2010-10-01', 'station': 'GHCND:USC00386153', 'zipcode': '29577', 'value': 178}
# {'date': '2010-10-01', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 211}
# {'date': '2010-10-01', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 211}
# {'date': '2010-10-03', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 61}
# {'date': '2010-10-04', 'station': 'GHCND:USC00404561', 'zipcode': '38301', 'value': 28}
# {'date': '2010-10-04', 'station': 'GHCND:USC00516198', 'zipcode': '96720', 'value': 156}
# {'date': '2010-10-08', 'station': 'GHCND:USC00313638', 'zipcode': '27834', 'value': 106}
# {'date': '2010-10-11', 'station': 'GHCND:USC00148847', 'zipcode': '67209', 'value': 122}
# {'date': '2010-10-11', 'station': 'GHCND:USC00084625', 'zipcode': '34741', 'value': 167}
# {'date': '2010-10-11', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 139}
# {'date': '2010-10-12', 'station': 'GHCND:USC00445204', 'zipcode': '20110', 'value': 144}
# {'date': '2010-10-14', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 239}
# {'date': '2010-10-14', 'station': 'GHCND:USW00013766', 'zipcode': '27954', 'value': 183}
# {'date': '2010-10-15', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 111}
# {'date': '2010-10-18', 'station': 'GHCND:USW00093914', 'zipcode': '75803', 'value': 172}
# {'date': '2010-10-19', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 156}
# {'date': '2010-10-20', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 217}
# {'date': '2010-10-21', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 50}
# {'date': '2010-10-21', 'station': 'GHCND:USC00144695', 'zipcode': '67901', 'value': 100}
# {'date': '2010-10-24', 'station': 'GHCND:USC00148847', 'zipcode': '67209', 'value': 133}
# {'date': '2010-10-26', 'station': 'GHCND:USC00415701', 'zipcode': '78503', 'value': 222}
# {'date': '2010-10-26', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 128}
# {'date': '2010-10-27', 'station': 'GHCND:USW00013766', 'zipcode': '27954', 'value': 250}
# {'date': '2010-10-27', 'station': 'GHCND:USC00226177', 'zipcode': '39120', 'value': 244}
# {'date': '2010-10-28', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': 39}
# {'date': '2010-10-28', 'station': 'GHCND:USC00504991', 'zipcode': '99615', 'value': 44}
# {'date': '2010-10-29', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 233}
# {'date': '2010-10-30', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 250}
# {'date': '2010-10-30', 'station': 'GHCND:USC00445204', 'zipcode': '20110', 'value': 17}
# {'date': '2010-10-31', 'station': 'GHCND:USC00190593', 'zipcode': '01915', 'value': 78}
# {'date': '2010-11-01', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 239}
# {'date': '2010-11-02', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 133}
# {'date': '2010-11-03', 'station': 'GHCND:USC00183353', 'zipcode': '21701', 'value': -22}
# {'date': '2010-11-03', 'station': 'GHCND:USC00046646', 'zipcode': '94303', 'value': 94}
# {'date': '2010-11-03', 'station': 'GHCND:USC00211891', 'zipcode': '56716', 'value': 33}
# {'date': '2010-11-04', 'station': 'GHCND:USC00221738', 'zipcode': '38732', 'value': 72}
# {'date': '2010-11-05', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 206}
# {'date': '2010-11-09', 'station': 'GHCND:USC00500657', 'zipcode': '99901', 'value': 17}
# {'date': '2010-11-12', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 189}
# {'date': '2010-11-15', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 67}
# {'date': '2010-11-16', 'station': 'GHCND:USC00242104', 'zipcode': '59901', 'value': 11}
# {'date': '2010-11-19', 'station': 'GHCND:USC00132999', 'zipcode': '50501', 'value': 11}
# {'date': '2010-11-21', 'station': 'GHCND:USC00422173', 'zipcode': '84078', 'value': -33}
# {'date': '2010-11-23', 'station': 'GHCND:USC00088942', 'zipcode': '32780', 'value': 167}
# {'date': '2010-11-30', 'station': 'GHCND:USC00107208', 'zipcode': '83204', 'value': -61}
# {'date': '2010-12-02', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 111}
# {'date': '2010-12-04', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 89}
# {'date': '2010-12-07', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 17}
# {'date': '2010-12-08', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 33}
# {'date': '2010-12-11', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 128}
# {'date': '2010-12-11', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'value': 100}
# {'date': '2010-12-16', 'station': 'GHCND:USC00413691', 'zipcode': '76051', 'value': 44}
# {'date': '2010-12-18', 'station': 'GHCND:USC00043256', 'zipcode': '93727', 'value': 117}
# {'date': '2010-12-22', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'value': 22}
# {'date': '2010-12-24', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 106}
# {'date': '2010-12-25', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'value': -6}
# {'date': '2010-12-25', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'value': 150}
# {'date': '2010-12-28', 'station': 'GHCND:USC00086078', 'zipcode': '34104', 'value': 11}
# {'date': '2010-12-30', 'station': 'GHCND:USC00421144', 'zipcode': '84083', 'value': -67}

# %% [markdown]
# From the documentation:
#
# ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt
#
# https://stackoverflow.com/questions/49280302/noaa-api-returning-impossible-historical-temperature-values
#
# TOBS = Temperature at the time of observation (tenths of degrees C). We can divide results by 10

# %%
df_w_weather.to_csv('df_w_weather.csv', index=False)

# %% [markdown]
# **Get data for 2 years?**

# %%
len(df_w_weather)
# Out:
# 540

# %% [markdown]
# **Import Precipitation (PRCP) data via API**

# %%
column_names = ["date", "station", "zipcode", "prcp_value"]

df_w_prcp = pd.DataFrame(columns = column_names)

# %%
for index,row in df_zip_date_2010.iterrows():
    response = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:'+row.zipcode+'&datatypeid=PRCP&startdate='+row.incident_date+'&enddate='+row.incident_date, 
                             headers={'token':Token_f})
    res_json = json.loads(response.text)
    if res_json != {}:
        new_row = {'date': row.incident_date, 'station': res_json['results'][0]['station'], 'zipcode': row.zipcode, 'prcp_value': res_json['results'][0]['value']}
        df_w_prcp = df_w_prcp.append(new_row, ignore_index=True)
        print(new_row)
# Out:
# {'date': '2010-01-01', 'station': 'GHCND:USW00092805', 'zipcode': '33060', 'prcp_value': 23}
# {'date': '2010-01-01', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 150}
# {'date': '2010-01-02', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 10}
# {'date': '2010-01-02', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-01-02', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-01-02', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 0}
# {'date': '2010-01-03', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-03', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-03', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-01-03', 'station': 'GHCND:USW00093228', 'zipcode': '94541', 'prcp_value': 0}
# {'date': '2010-01-04', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-01-05', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-05', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-05', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-06', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-01-06', 'station': 'GHCND:USW00023293', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-01-06', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-01-06', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-01-07', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 3}
# {'date': '2010-01-07', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-01-08', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 13}
# {'date': '2010-01-09', 'station': 'GHCND:US1FLDV0037', 'zipcode': '32218', 'prcp_value': 3}
# {'date': '2010-01-09', 'station': 'GHCND:US1AZMR0013', 'zipcode': '85260', 'prcp_value': 0}
# {'date': '2010-01-10', 'station': 'GHCND:USW00022536', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-01-10', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-01-10', 'station': 'GHCND:USW00013968', 'zipcode': '74115', 'prcp_value': 0}
# {'date': '2010-01-10', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'prcp_value': 0}
# {'date': '2010-01-10', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-01-11', 'station': 'GHCND:USW00013995', 'zipcode': '65803', 'prcp_value': 0}
# {'date': '2010-01-11', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-01-11', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-01-12', 'station': 'GHCND:USW00014740', 'zipcode': '06096', 'prcp_value': 0}
# {'date': '2010-01-12', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-01-13', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 3}
# {'date': '2010-01-13', 'station': 'GHCND:USW00023293', 'zipcode': '95110', 'prcp_value': 46}
# {'date': '2010-01-14', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-01-15', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-01-15', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 0}
# {'date': '2010-01-16', 'station': 'GHCND:US1CASJ0006', 'zipcode': '95206', 'prcp_value': 0}
# {'date': '2010-01-16', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-16', 'station': 'GHCND:USC00516395', 'zipcode': '96818', 'prcp_value': 0}
# {'date': '2010-01-16', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-01-16', 'station': 'GHCND:USC00502587', 'zipcode': '99685', 'prcp_value': 3}
# {'date': '2010-01-16', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 18}
# {'date': '2010-01-17', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 28}
# {'date': '2010-01-17', 'station': 'GHCND:USC00046572', 'zipcode': '93030', 'prcp_value': 292}
# {'date': '2010-01-17', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 28}
# {'date': '2010-01-17', 'station': 'GHCND:USW00013722', 'zipcode': '27560', 'prcp_value': 371}
# {'date': '2010-01-17', 'station': 'GHCND:USC00511038', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-01-18', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-01-19', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-01-19', 'station': 'GHCND:USC00500275', 'zipcode': '99502', 'prcp_value': 0}
# {'date': '2010-01-19', 'station': 'GHCND:US1MTMS0009', 'zipcode': '59808', 'prcp_value': 3}
# {'date': '2010-01-19', 'station': 'GHCND:USC00511038', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-01-20', 'station': 'GHCND:USW00014765', 'zipcode': '02886', 'prcp_value': 0}
# {'date': '2010-01-20', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-01-20', 'station': 'GHCND:USC00511038', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-01-21', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-01-22', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-01-22', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-01-23', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 33}
# {'date': '2010-01-24', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 20}
# {'date': '2010-01-24', 'station': 'GHCND:USW00054787', 'zipcode': '11735', 'prcp_value': 0}
# {'date': '2010-01-25', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 71}
# {'date': '2010-01-25', 'station': 'GHCND:USW00023050', 'zipcode': '87116', 'prcp_value': 0}
# {'date': '2010-01-26', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 0}
# {'date': '2010-01-27', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-01-27', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-01-27', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-01-27', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 5}
# {'date': '2010-01-28', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-01-28', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-01-28', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-01-29', 'station': 'GHCND:US1KSFI0002', 'zipcode': '67846', 'prcp_value': 175}
# {'date': '2010-01-29', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 5}
# {'date': '2010-01-30', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-01-30', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-02-01', 'station': 'GHCND:US1ILWM0005', 'zipcode': '62959', 'prcp_value': 0}
# {'date': '2010-02-01', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 157}
# {'date': '2010-02-02', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-02-04', 'station': 'GHCND:US1ARWS0008', 'zipcode': '72764', 'prcp_value': 0}
# {'date': '2010-02-04', 'station': 'GHCND:US1TXCMR012', 'zipcode': '78550', 'prcp_value': 457}
# {'date': '2010-02-05', 'station': 'GHCND:US1CASB0001', 'zipcode': '93117', 'prcp_value': 137}
# {'date': '2010-02-05', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 25}
# {'date': '2010-02-06', 'station': 'GHCND:USW00013876', 'zipcode': '35212', 'prcp_value': 0}
# {'date': '2010-02-06', 'station': 'GHCND:USC00518543', 'zipcode': '96732', 'prcp_value': 0}
# {'date': '2010-02-06', 'station': 'GHCND:USW00022536', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-02-09', 'station': 'GHCND:USW00093037', 'zipcode': '80916', 'prcp_value': 0}
# {'date': '2010-02-09', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-02-10', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-02-10', 'station': 'GHCND:USW00012960', 'zipcode': '77032', 'prcp_value': 3}
# {'date': '2010-02-12', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-02-12', 'station': 'GHCND:USW00012873', 'zipcode': '33762', 'prcp_value': 188}
# {'date': '2010-02-13', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-02-13', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-02-15', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-02-15', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-02-16', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-02-16', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-02-17', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-02-18', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-02-18', 'station': 'GHCND:USW00014737', 'zipcode': '18109', 'prcp_value': 0}
# {'date': '2010-02-20', 'station': 'GHCND:US1KSSA0006', 'zipcode': '67401', 'prcp_value': 0}
# {'date': '2010-02-21', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 5}
# {'date': '2010-02-21', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-02-22', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-02-23', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-02-24', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 0}
# {'date': '2010-02-25', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-02-26', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-02-28', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-03-01', 'station': 'GHCND:USC00454769', 'zipcode': '98626', 'prcp_value': 0}
# {'date': '2010-03-02', 'station': 'GHCND:USW00013781', 'zipcode': '19720', 'prcp_value': 13}
# {'date': '2010-03-02', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-03-03', 'station': 'GHCND:US1KSTH0017', 'zipcode': '67701', 'prcp_value': 0}
# {'date': '2010-03-03', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-03-04', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-03-04', 'station': 'GHCND:USW00014737', 'zipcode': '18109', 'prcp_value': 0}
# {'date': '2010-03-04', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-03-05', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-03-05', 'station': 'GHCND:USC00088942', 'zipcode': '32780', 'prcp_value': 0}
# {'date': '2010-03-06', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 229}
# {'date': '2010-03-06', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-03-06', 'station': 'GHCND:US1INSJ0027', 'zipcode': '46628', 'prcp_value': 0}
# {'date': '2010-03-07', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-03-07', 'station': 'GHCND:US1SCCR0049', 'zipcode': '29404', 'prcp_value': 0}
# {'date': '2010-03-07', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 56}
# {'date': '2010-03-08', 'station': 'GHCND:US1TXBXR112', 'zipcode': '78216', 'prcp_value': 89}
# {'date': '2010-03-08', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-03-08', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 71}
# {'date': '2010-03-08', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 71}
# {'date': '2010-03-09', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-03-09', 'station': 'GHCND:USW00013722', 'zipcode': '27560', 'prcp_value': 0}
# {'date': '2010-03-09', 'station': 'GHCND:USC00183353', 'zipcode': '21701', 'prcp_value': 0}
# {'date': '2010-03-09', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-03-10', 'station': 'GHCND:USC00454769', 'zipcode': '98626', 'prcp_value': 18}
# {'date': '2010-03-10', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'prcp_value': 0}
# {'date': '2010-03-10', 'station': 'GHCND:US1INMR0013', 'zipcode': '46241', 'prcp_value': 10}
# {'date': '2010-03-11', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-03-11', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-03-12', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-03-12', 'station': 'GHCND:USC00412011', 'zipcode': '78406', 'prcp_value': 0}
# {'date': '2010-03-12', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 305}
# {'date': '2010-03-14', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 0}
# {'date': '2010-03-15', 'station': 'GHCND:USW00023169', 'zipcode': '89119', 'prcp_value': 0}
# {'date': '2010-03-15', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 0}
# {'date': '2010-03-15', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-03-15', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-03-16', 'station': 'GHCND:US1TXMDL013', 'zipcode': '79706', 'prcp_value': 173}
# {'date': '2010-03-17', 'station': 'GHCND:USW00023169', 'zipcode': '89119', 'prcp_value': 0}
# {'date': '2010-03-18', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-03-18', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-03-18', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-03-18', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-03-19', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 0}
# {'date': '2010-03-19', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-03-19', 'station': 'GHCND:USW00013876', 'zipcode': '35212', 'prcp_value': 0}
# {'date': '2010-03-19', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 0}
# {'date': '2010-03-20', 'station': 'GHCND:USW00014710', 'zipcode': '03103', 'prcp_value': 0}
# {'date': '2010-03-20', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-03-21', 'station': 'GHCND:USW00014757', 'zipcode': '12590', 'prcp_value': 0}
# {'date': '2010-03-21', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-03-22', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 231}
# {'date': '2010-03-22', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-03-23', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-03-23', 'station': 'GHCND:USW00012841', 'zipcode': '32803', 'prcp_value': 0}
# {'date': '2010-03-23', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 0}
# {'date': '2010-03-24', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-03-25', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-03-25', 'station': 'GHCND:US1TXBXR112', 'zipcode': '78216', 'prcp_value': 119}
# {'date': '2010-03-25', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-03-26', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-03-26', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 13}
# {'date': '2010-03-27', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'prcp_value': 0}
# {'date': '2010-03-27', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-03-28', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-03-28', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 300}
# {'date': '2010-03-28', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 300}
# {'date': '2010-03-29', 'station': 'GHCND:USW00014733', 'zipcode': '14225', 'prcp_value': 8}
# {'date': '2010-03-30', 'station': 'GHCND:US1ILWN0010', 'zipcode': '61109', 'prcp_value': 0}
# {'date': '2010-03-30', 'station': 'GHCND:US1GACT0028', 'zipcode': '31408', 'prcp_value': 0}
# {'date': '2010-03-31', 'station': 'GHCND:US1NYCM0008', 'zipcode': '14845', 'prcp_value': 38}
# {'date': '2010-03-31', 'station': 'GHCND:USW00026615', 'zipcode': '99559', 'prcp_value': 8}
# {'date': '2010-03-31', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 94}
# {'date': '2010-03-31', 'station': 'GHCND:USW00024233', 'zipcode': '98158', 'prcp_value': 0}
# {'date': '2010-04-01', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-04-02', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-04-02', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 18}
# {'date': '2010-04-03', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-04-03', 'station': 'GHCND:USW00024233', 'zipcode': '98158', 'prcp_value': 43}
# {'date': '2010-04-03', 'station': 'GHCND:USW00014740', 'zipcode': '06096', 'prcp_value': 0}
# {'date': '2010-04-03', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-04-03', 'station': 'GHCND:USC00047298', 'zipcode': '96002', 'prcp_value': 0}
# {'date': '2010-04-04', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 3}
# {'date': '2010-04-04', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 20}
# {'date': '2010-04-04', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 3}
# {'date': '2010-04-04', 'station': 'GHCND:USW00023130', 'zipcode': '91406', 'prcp_value': 5}
# {'date': '2010-04-04', 'station': 'GHCND:USW00023130', 'zipcode': '91406', 'prcp_value': 5}
# {'date': '2010-04-05', 'station': 'GHCND:US1ARPS0012', 'zipcode': '72206', 'prcp_value': 0}
# {'date': '2010-04-05', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-06', 'station': 'GHCND:US1KYBN0004', 'zipcode': '41042', 'prcp_value': 117}
# {'date': '2010-04-06', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-04-07', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'prcp_value': 0}
# {'date': '2010-04-09', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-04-09', 'station': 'GHCND:USW00003102', 'zipcode': '91761', 'prcp_value': 0}
# {'date': '2010-04-09', 'station': 'GHCND:USC00503605', 'zipcode': '99835', 'prcp_value': 10}
# {'date': '2010-04-09', 'station': 'GHCND:USC00158555', 'zipcode': '42086', 'prcp_value': 0}
# {'date': '2010-04-09', 'station': 'GHCND:USC00063207', 'zipcode': '06340', 'prcp_value': 201}
# {'date': '2010-04-10', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:US1INMR0013', 'zipcode': '46241', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:US1PADP0014', 'zipcode': '17057', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-04-10', 'station': 'GHCND:USW00004781', 'zipcode': '11779', 'prcp_value': 0}
# {'date': '2010-04-11', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 0}
# {'date': '2010-04-11', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-04-11', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-04-11', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-04-11', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-04-12', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 137}
# {'date': '2010-04-12', 'station': 'GHCND:USW00013722', 'zipcode': '27560', 'prcp_value': 0}
# {'date': '2010-04-12', 'station': 'GHCND:USW00014792', 'zipcode': '08628', 'prcp_value': 0}
# {'date': '2010-04-12', 'station': 'GHCND:US1KYBN0004', 'zipcode': '41042', 'prcp_value': 0}
# {'date': '2010-04-12', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 127}
# {'date': '2010-04-13', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 0}
# {'date': '2010-04-13', 'station': 'GHCND:USC00168923', 'zipcode': '71282', 'prcp_value': 0}
# {'date': '2010-04-13', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-04-14', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 0}
# {'date': '2010-04-14', 'station': 'GHCND:USW00094830', 'zipcode': '43558', 'prcp_value': 0}
# {'date': '2010-04-14', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-04-16', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'prcp_value': 0}
# {'date': '2010-04-16', 'station': 'GHCND:USW00013893', 'zipcode': '38116', 'prcp_value': 0}
# {'date': '2010-04-16', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-04-16', 'station': 'GHCND:USW00004853', 'zipcode': '44114', 'prcp_value': 41}
# {'date': '2010-04-16', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-04-16', 'station': 'GHCND:USW00023047', 'zipcode': '79111', 'prcp_value': 312}
# {'date': '2010-04-16', 'station': 'GHCND:USW00094741', 'zipcode': '07608', 'prcp_value': 76}
# {'date': '2010-04-16', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-04-18', 'station': 'GHCND:USW00093909', 'zipcode': '66031', 'prcp_value': 0}
# {'date': '2010-04-18', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-04-18', 'station': 'GHCND:USC00518543', 'zipcode': '96732', 'prcp_value': 0}
# {'date': '2010-04-19', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-04-19', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 25}
# {'date': '2010-04-19', 'station': 'GHCND:USW00012854', 'zipcode': '32773', 'prcp_value': 33}
# {'date': '2010-04-19', 'station': 'GHCND:USW00024233', 'zipcode': '98158', 'prcp_value': 0}
# {'date': '2010-04-19', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-04-20', 'station': 'GHCND:USC00323621', 'zipcode': '58203', 'prcp_value': 0}
# {'date': '2010-04-20', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-20', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-21', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-04-21', 'station': 'GHCND:USW00013876', 'zipcode': '35212', 'prcp_value': 0}
# {'date': '2010-04-21', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-04-21', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 81}
# {'date': '2010-04-21', 'station': 'GHCND:USC00516395', 'zipcode': '96818', 'prcp_value': 8}
# {'date': '2010-04-21', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-21', 'station': 'GHCND:US1NCBF0002', 'zipcode': '27889', 'prcp_value': 86}
# {'date': '2010-04-21', 'station': 'GHCND:USW00024110', 'zipcode': '98837', 'prcp_value': 0}
# {'date': '2010-04-22', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 10}
# {'date': '2010-04-22', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-04-22', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-04-22', 'station': 'GHCND:USC00111160', 'zipcode': '62206', 'prcp_value': 0}
# {'date': '2010-04-23', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 13}
# {'date': '2010-04-23', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-04-23', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-04-23', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-04-23', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-04-23', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 79}
# {'date': '2010-04-23', 'station': 'GHCND:USC00214418', 'zipcode': '54603', 'prcp_value': 0}
# {'date': '2010-04-24', 'station': 'GHCND:US1UTWB0009', 'zipcode': '84405', 'prcp_value': 28}
# {'date': '2010-04-24', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 5}
# {'date': '2010-04-24', 'station': 'GHCND:US1SCOC0020', 'zipcode': '29678', 'prcp_value': 28}
# {'date': '2010-04-25', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 0}
# {'date': '2010-04-25', 'station': 'GHCND:US1PADP0014', 'zipcode': '17057', 'prcp_value': 109}
# {'date': '2010-04-25', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 0}
# {'date': '2010-04-25', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 693}
# {'date': '2010-04-26', 'station': 'GHCND:US10lanc033', 'zipcode': '68524', 'prcp_value': 0}
# {'date': '2010-04-26', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 0}
# {'date': '2010-04-26', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-04-26', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'prcp_value': 56}
# {'date': '2010-04-26', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 0}
# {'date': '2010-04-26', 'station': 'GHCND:USW00023169', 'zipcode': '89119', 'prcp_value': 0}
# {'date': '2010-04-26', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-04-27', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 15}
# {'date': '2010-04-27', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 3}
# {'date': '2010-04-28', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 13}
# {'date': '2010-04-28', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-04-28', 'station': 'GHCND:USW00014839', 'zipcode': '53207', 'prcp_value': 0}
# {'date': '2010-04-28', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 13}
# {'date': '2010-04-28', 'station': 'GHCND:US1NJAT0013', 'zipcode': '08234', 'prcp_value': 0}
# {'date': '2010-04-28', 'station': 'GHCND:USC00478937', 'zipcode': '53188', 'prcp_value': 0}
# {'date': '2010-04-28', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 36}
# {'date': '2010-04-28', 'station': 'GHCND:US1MAES0002', 'zipcode': '01915', 'prcp_value': 30}
# {'date': '2010-04-28', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-04-29', 'station': 'GHCND:US1NVWH0078', 'zipcode': '89502', 'prcp_value': 5}
# {'date': '2010-04-29', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 0}
# {'date': '2010-04-29', 'station': 'GHCND:US1KYBN0004', 'zipcode': '41042', 'prcp_value': 0}
# {'date': '2010-04-29', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-04-29', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'prcp_value': 0}
# {'date': '2010-04-30', 'station': 'GHCND:US1ARPS0012', 'zipcode': '72206', 'prcp_value': 0}
# {'date': '2010-04-30', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 0}
# {'date': '2010-04-30', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 236}
# {'date': '2010-04-30', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 13}
# {'date': '2010-04-30', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-04-30', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 13}
# {'date': '2010-05-01', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 0}
# {'date': '2010-05-01', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-05-01', 'station': 'GHCND:USW00014735', 'zipcode': '12110', 'prcp_value': 0}
# {'date': '2010-05-02', 'station': 'GHCND:USW00023129', 'zipcode': '90807', 'prcp_value': 0}
# {'date': '2010-05-02', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-05-03', 'station': 'GHCND:US1PADP0014', 'zipcode': '17057', 'prcp_value': 826}
# {'date': '2010-05-03', 'station': 'GHCND:US1NDCS0004', 'zipcode': '58102', 'prcp_value': 13}
# {'date': '2010-05-03', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 373}
# {'date': '2010-05-03', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-05-03', 'station': 'GHCND:USW00094745', 'zipcode': '10604', 'prcp_value': 274}
# {'date': '2010-05-03', 'station': 'GHCND:US1NVEL0009', 'zipcode': '89801', 'prcp_value': 0}
# {'date': '2010-05-03', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-05-04', 'station': 'GHCND:USW00023169', 'zipcode': '89119', 'prcp_value': 0}
# {'date': '2010-05-05', 'station': 'GHCND:USW00023160', 'zipcode': '85756', 'prcp_value': 0}
# {'date': '2010-05-05', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-05-05', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-05-05', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-05-05', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-05-06', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 0}
# {'date': '2010-05-06', 'station': 'GHCND:USW00013866', 'zipcode': '25311', 'prcp_value': 0}
# {'date': '2010-05-06', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-05-06', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 0}
# {'date': '2010-05-06', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 10}
# {'date': '2010-05-06', 'station': 'GHCND:US1WIBN0006', 'zipcode': '54313', 'prcp_value': 0}
# {'date': '2010-05-07', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 0}
# {'date': '2010-05-07', 'station': 'GHCND:US1ILWN0010', 'zipcode': '61109', 'prcp_value': 122}
# {'date': '2010-05-07', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 23}
# {'date': '2010-05-07', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-05-07', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-05-07', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 33}
# {'date': '2010-05-08', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-08', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-05-08', 'station': 'GHCND:USW00003159', 'zipcode': '93536', 'prcp_value': 0}
# {'date': '2010-05-08', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-05-08', 'station': 'GHCND:USW00014939', 'zipcode': '68524', 'prcp_value': 0}
# {'date': '2010-05-08', 'station': 'GHCND:USW00013722', 'zipcode': '27560', 'prcp_value': 0}
# {'date': '2010-05-09', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 10}
# {'date': '2010-05-09', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 0}
# {'date': '2010-05-09', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-05-09', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-09', 'station': 'GHCND:USW00014733', 'zipcode': '14225', 'prcp_value': 3}
# {'date': '2010-05-10', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-05-10', 'station': 'GHCND:USW00013882', 'zipcode': '37421', 'prcp_value': 33}
# {'date': '2010-05-10', 'station': 'GHCND:USW00012916', 'zipcode': '70062', 'prcp_value': 0}
# {'date': '2010-05-10', 'station': 'GHCND:USW00023185', 'zipcode': '89502', 'prcp_value': 15}
# {'date': '2010-05-10', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-10', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-05-10', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-05-10', 'station': 'GHCND:USC00101024', 'zipcode': '83705', 'prcp_value': 38}
# {'date': '2010-05-10', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-11', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-05-11', 'station': 'GHCND:USC00148847', 'zipcode': '67209', 'prcp_value': 5}
# {'date': '2010-05-11', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-05-11', 'station': 'GHCND:USW00013743', 'zipcode': '22202', 'prcp_value': 28}
# {'date': '2010-05-11', 'station': 'GHCND:USW00013743', 'zipcode': '22202', 'prcp_value': 28}
# {'date': '2010-05-12', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-05-12', 'station': 'GHCND:US1AKFN0004', 'zipcode': '99709', 'prcp_value': 0}
# {'date': '2010-05-12', 'station': 'GHCND:USW00003966', 'zipcode': '63005', 'prcp_value': 259}
# {'date': '2010-05-12', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:US1TXLK0004', 'zipcode': '79403', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 114}
# {'date': '2010-05-13', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-05-13', 'station': 'GHCND:US1INMR0013', 'zipcode': '46241', 'prcp_value': 94}
# {'date': '2010-05-14', 'station': 'GHCND:USW00023050', 'zipcode': '87116', 'prcp_value': 0}
# {'date': '2010-05-15', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 0}
# {'date': '2010-05-15', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 180}
# {'date': '2010-05-15', 'station': 'GHCND:USC00101024', 'zipcode': '83705', 'prcp_value': 0}
# {'date': '2010-05-15', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 0}
# {'date': '2010-05-15', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 180}
# {'date': '2010-05-15', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 180}
# {'date': '2010-05-16', 'station': 'GHCND:US1AKFN0004', 'zipcode': '99709', 'prcp_value': 0}
# {'date': '2010-05-16', 'station': 'GHCND:USW00014922', 'zipcode': '55107', 'prcp_value': 0}
# {'date': '2010-05-16', 'station': 'GHCND:USW00014740', 'zipcode': '06096', 'prcp_value': 0}
# {'date': '2010-05-16', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 0}
# {'date': '2010-05-16', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 94}
# {'date': '2010-05-16', 'station': 'GHCND:USW00014710', 'zipcode': '03103', 'prcp_value': 0}
# {'date': '2010-05-16', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-05-17', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-05-17', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 259}
# {'date': '2010-05-17', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-05-17', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-05-18', 'station': 'GHCND:US1WIJF0002', 'zipcode': '53094', 'prcp_value': 0}
# {'date': '2010-05-18', 'station': 'GHCND:USC00504812', 'zipcode': '99615', 'prcp_value': 0}
# {'date': '2010-05-18', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 0}
# {'date': '2010-05-18', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 94}
# {'date': '2010-05-18', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-05-18', 'station': 'GHCND:US1LALY0002', 'zipcode': '70508', 'prcp_value': 0}
# {'date': '2010-05-19', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-19', 'station': 'GHCND:USW00014758', 'zipcode': '06512', 'prcp_value': 20}
# {'date': '2010-05-19', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-05-19', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00013866', 'zipcode': '25311', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-05-20', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-05-21', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-21', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 5}
# {'date': '2010-05-22', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-05-22', 'station': 'GHCND:US1GACT0028', 'zipcode': '31408', 'prcp_value': 10}
# {'date': '2010-05-22', 'station': 'GHCND:US1WATH0001', 'zipcode': '98501', 'prcp_value': 61}
# {'date': '2010-05-23', 'station': 'GHCND:USW00093110', 'zipcode': '93030', 'prcp_value': 0}
# {'date': '2010-05-23', 'station': 'GHCND:VQC00677600', 'zipcode': '00802', 'prcp_value': 0}
# {'date': '2010-05-23', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 0}
# {'date': '2010-05-23', 'station': 'GHCND:US1FLDV0037', 'zipcode': '32218', 'prcp_value': 0}
# {'date': '2010-05-24', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-05-24', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-05-24', 'station': 'GHCND:US1UTIR0003', 'zipcode': '84721', 'prcp_value': 0}
# {'date': '2010-05-24', 'station': 'GHCND:USC00111160', 'zipcode': '62206', 'prcp_value': 0}
# {'date': '2010-05-24', 'station': 'GHCND:USW00094726', 'zipcode': '02745', 'prcp_value': 0}
# {'date': '2010-05-25', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-05-25', 'station': 'GHCND:USW00003031', 'zipcode': '79765', 'prcp_value': 0}
# {'date': '2010-05-25', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-05-25', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-05-25', 'station': 'GHCND:USC00511038', 'zipcode': '96766', 'prcp_value': 102}
# {'date': '2010-05-25', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-05-26', 'station': 'GHCND:USW00014837', 'zipcode': '53704', 'prcp_value': 8}
# {'date': '2010-05-26', 'station': 'GHCND:US1TXEP0025', 'zipcode': '79925', 'prcp_value': 0}
# {'date': '2010-05-26', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-05-27', 'station': 'GHCND:USW00013893', 'zipcode': '38116', 'prcp_value': 0}
# {'date': '2010-05-27', 'station': 'GHCND:USW00014820', 'zipcode': '44135', 'prcp_value': 0}
# {'date': '2010-05-27', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-05-28', 'station': 'GHCND:USW00013866', 'zipcode': '25311', 'prcp_value': 0}
# {'date': '2010-05-28', 'station': 'GHCND:USC00122731', 'zipcode': '47725', 'prcp_value': 58}
# {'date': '2010-05-28', 'station': 'GHCND:USC00245608', 'zipcode': '59714', 'prcp_value': 0}
# {'date': '2010-05-28', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 30}
# {'date': '2010-05-28', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-05-31', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00094815', 'zipcode': '49002', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 46}
# {'date': '2010-06-01', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 429}
# {'date': '2010-06-01', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USC00504812', 'zipcode': '99615', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-06-01', 'station': 'GHCND:USW00014839', 'zipcode': '53207', 'prcp_value': 0}
# {'date': '2010-06-02', 'station': 'GHCND:US1KYBN0004', 'zipcode': '41042', 'prcp_value': 10}
# {'date': '2010-06-02', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-06-02', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 221}
# {'date': '2010-06-02', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-06-03', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-06-03', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-06-03', 'station': 'GHCND:USW00012841', 'zipcode': '32803', 'prcp_value': 28}
# {'date': '2010-06-03', 'station': 'GHCND:USC00026796', 'zipcode': '86301', 'prcp_value': 0}
# {'date': '2010-06-03', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-06-04', 'station': 'GHCND:US1MSRN0014', 'zipcode': '39208', 'prcp_value': 5}
# {'date': '2010-06-04', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 0}
# {'date': '2010-06-05', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 38}
# {'date': '2010-06-06', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-06-07', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-06-07', 'station': 'GHCND:USW00013876', 'zipcode': '35212', 'prcp_value': 0}
# {'date': '2010-06-07', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-06-07', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 114}
# {'date': '2010-06-08', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00023160', 'zipcode': '85756', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:USW00013970', 'zipcode': '70807', 'prcp_value': 5}
# {'date': '2010-06-08', 'station': 'GHCND:USW00024234', 'zipcode': '98108', 'prcp_value': 66}
# {'date': '2010-06-08', 'station': 'GHCND:USW00012960', 'zipcode': '77032', 'prcp_value': 74}
# {'date': '2010-06-08', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-06-08', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-06-09', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-06-09', 'station': 'GHCND:US1NJMS0003', 'zipcode': '07960', 'prcp_value': 0}
# {'date': '2010-06-09', 'station': 'GHCND:USW00012960', 'zipcode': '77032', 'prcp_value': 0}
# {'date': '2010-06-09', 'station': 'GHCND:US1MSHR0007', 'zipcode': '39503', 'prcp_value': 0}
# {'date': '2010-06-10', 'station': 'GHCND:US1WAWM0004', 'zipcode': '99163', 'prcp_value': 51}
# {'date': '2010-06-10', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-06-10', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-06-10', 'station': 'GHCND:USC00183353', 'zipcode': '21701', 'prcp_value': 150}
# {'date': '2010-06-11', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 175}
# {'date': '2010-06-11', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-06-11', 'station': 'GHCND:US1INMR0013', 'zipcode': '46241', 'prcp_value': 0}
# {'date': '2010-06-11', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-06-11', 'station': 'GHCND:USW00014820', 'zipcode': '44135', 'prcp_value': 0}
# {'date': '2010-06-11', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-06-12', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 165}
# {'date': '2010-06-12', 'station': 'GHCND:VQC00679450', 'zipcode': '00802', 'prcp_value': 0}
# {'date': '2010-06-13', 'station': 'GHCND:US1COLP0038', 'zipcode': '81137', 'prcp_value': 8}
# {'date': '2010-06-13', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 8}
# {'date': '2010-06-13', 'station': 'GHCND:USW00003947', 'zipcode': '64153', 'prcp_value': 94}
# {'date': '2010-06-13', 'station': 'GHCND:USC00502107', 'zipcode': '99709', 'prcp_value': 91}
# {'date': '2010-06-13', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 0}
# {'date': '2010-06-14', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 0}
# {'date': '2010-06-14', 'station': 'GHCND:USW00013876', 'zipcode': '35212', 'prcp_value': 267}
# {'date': '2010-06-14', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 0}
# {'date': '2010-06-14', 'station': 'GHCND:USW00014933', 'zipcode': '50321', 'prcp_value': 109}
# {'date': '2010-06-15', 'station': 'GHCND:USW00012960', 'zipcode': '77032', 'prcp_value': 0}
# {'date': '2010-06-15', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 3}
# {'date': '2010-06-15', 'station': 'GHCND:USW00023188', 'zipcode': '92101', 'prcp_value': 0}
# {'date': '2010-06-16', 'station': 'GHCND:US1INMR0013', 'zipcode': '46241', 'prcp_value': 76}
# {'date': '2010-06-16', 'station': 'GHCND:US1KSRL0008', 'zipcode': '66503', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:USW00013893', 'zipcode': '38116', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:USW00014821', 'zipcode': '43219', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 3}
# {'date': '2010-06-17', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 0}
# {'date': '2010-06-17', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 3}
# {'date': '2010-06-17', 'station': 'GHCND:USW00024127', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-06-18', 'station': 'GHCND:US1NYSL0006', 'zipcode': '13676', 'prcp_value': 33}
# {'date': '2010-06-18', 'station': 'GHCND:USW00014839', 'zipcode': '53207', 'prcp_value': 84}
# {'date': '2010-06-18', 'station': 'GHCND:USW00023136', 'zipcode': '93010', 'prcp_value': 0}
# {'date': '2010-06-18', 'station': 'GHCND:US1NVWH0078', 'zipcode': '89502', 'prcp_value': 0}
# {'date': '2010-06-18', 'station': 'GHCND:USC00511065', 'zipcode': '96720', 'prcp_value': 0}
# {'date': '2010-06-18', 'station': 'GHCND:USW00003102', 'zipcode': '91761', 'prcp_value': 0}
# {'date': '2010-06-19', 'station': 'GHCND:USC00518543', 'zipcode': '96732', 'prcp_value': 0}
# {'date': '2010-06-19', 'station': 'GHCND:US1CASC0037', 'zipcode': '95110', 'prcp_value': 0}
# ...
# {'date': '2010-11-01', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-11-01', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-11-01', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-11-01', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 394}
# {'date': '2010-11-02', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-11-02', 'station': 'GHCND:USW00014740', 'zipcode': '06096', 'prcp_value': 0}
# {'date': '2010-11-02', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-11-02', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-11-02', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 0}
# {'date': '2010-11-02', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-11-03', 'station': 'GHCND:US1MDFR0009', 'zipcode': '21701', 'prcp_value': 0}
# {'date': '2010-11-03', 'station': 'GHCND:USC00046646', 'zipcode': '94303', 'prcp_value': 0}
# {'date': '2010-11-03', 'station': 'GHCND:USW00014839', 'zipcode': '53207', 'prcp_value': 0}
# {'date': '2010-11-03', 'station': 'GHCND:USC00211891', 'zipcode': '56716', 'prcp_value': 8}
# {'date': '2010-11-03', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-11-03', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-11-03', 'station': 'GHCND:USW00023183', 'zipcode': '85034', 'prcp_value': 0}
# {'date': '2010-11-04', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 353}
# {'date': '2010-11-04', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-11-04', 'station': 'GHCND:US1UTSL0085', 'zipcode': '84116', 'prcp_value': 0}
# {'date': '2010-11-04', 'station': 'GHCND:USC00221738', 'zipcode': '38732', 'prcp_value': 0}
# {'date': '2010-11-05', 'station': 'GHCND:USW00014820', 'zipcode': '44135', 'prcp_value': 33}
# {'date': '2010-11-05', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-11-05', 'station': 'GHCND:USW00093718', 'zipcode': '29577', 'prcp_value': 3}
# {'date': '2010-11-05', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-11-05', 'station': 'GHCND:US1WASJ0001', 'zipcode': '98250', 'prcp_value': 3}
# {'date': '2010-11-05', 'station': 'GHCND:USW00013874', 'zipcode': '30337', 'prcp_value': 3}
# {'date': '2010-11-05', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 23}
# {'date': '2010-11-06', 'station': 'GHCND:USW00023169', 'zipcode': '89119', 'prcp_value': 0}
# {'date': '2010-11-06', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-11-06', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-11-06', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-11-06', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-11-07', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 142}
# {'date': '2010-11-08', 'station': 'GHCND:USW00014942', 'zipcode': '68110', 'prcp_value': 0}
# {'date': '2010-11-08', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 79}
# {'date': '2010-11-08', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-11-08', 'station': 'GHCND:USW00023293', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-11-09', 'station': 'GHCND:USC00500657', 'zipcode': '99901', 'prcp_value': 0}
# {'date': '2010-11-09', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-11-09', 'station': 'GHCND:USW00014735', 'zipcode': '12110', 'prcp_value': 3}
# {'date': '2010-11-09', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 8}
# {'date': '2010-11-09', 'station': 'GHCND:USW00023230', 'zipcode': '94621', 'prcp_value': 8}
# {'date': '2010-11-09', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-11-09', 'station': 'GHCND:USW00012918', 'zipcode': '77061', 'prcp_value': 0}
# {'date': '2010-11-09', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 38}
# {'date': '2010-11-09', 'station': 'GHCND:US1FLDV0033', 'zipcode': '32221', 'prcp_value': 0}
# {'date': '2010-11-10', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-11-10', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-11-10', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-11-10', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-11-10', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-11-11', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-11-11', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-11-11', 'station': 'GHCND:USW00093721', 'zipcode': '21240', 'prcp_value': 0}
# {'date': '2010-11-11', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-11-11', 'station': 'GHCND:USW00014737', 'zipcode': '18109', 'prcp_value': 0}
# {'date': '2010-11-12', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-11-12', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 64}
# {'date': '2010-11-12', 'station': 'GHCND:USW00014710', 'zipcode': '03103', 'prcp_value': 0}
# {'date': '2010-11-13', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-11-13', 'station': 'GHCND:USW00022536', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-11-13', 'station': 'GHCND:USW00012844', 'zipcode': '33406', 'prcp_value': 0}
# {'date': '2010-11-13', 'station': 'GHCND:USW00014820', 'zipcode': '44135', 'prcp_value': 0}
# {'date': '2010-11-14', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-11-15', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 0}
# {'date': '2010-11-15', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-11-15', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-11-15', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-11-15', 'station': 'GHCND:US1UTSL0085', 'zipcode': '84116', 'prcp_value': 33}
# {'date': '2010-11-16', 'station': 'GHCND:US1MTFH0013', 'zipcode': '59901', 'prcp_value': 130}
# {'date': '2010-11-16', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 38}
# {'date': '2010-11-16', 'station': 'GHCND:USW00012916', 'zipcode': '70062', 'prcp_value': 0}
# {'date': '2010-11-16', 'station': 'GHCND:US1UTSL0085', 'zipcode': '84116', 'prcp_value': 8}
# {'date': '2010-11-16', 'station': 'GHCND:USW00013838', 'zipcode': '36615', 'prcp_value': 20}
# {'date': '2010-11-17', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 114}
# {'date': '2010-11-17', 'station': 'GHCND:USW00023047', 'zipcode': '79111', 'prcp_value': 0}
# {'date': '2010-11-17', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-11-17', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-11-17', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-11-18', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 0}
# {'date': '2010-11-18', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-11-19', 'station': 'GHCND:USW00093909', 'zipcode': '66031', 'prcp_value': 0}
# {'date': '2010-11-19', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-11-19', 'station': 'GHCND:US1IAWB0003', 'zipcode': '50501', 'prcp_value': 0}
# {'date': '2010-11-20', 'station': 'GHCND:USW00094261', 'zipcode': '97124', 'prcp_value': 43}
# {'date': '2010-11-21', 'station': 'GHCND:US1SCLX0008', 'zipcode': '29170', 'prcp_value': 0}
# {'date': '2010-11-21', 'station': 'GHCND:US1UTUN0001', 'zipcode': '84078', 'prcp_value': 18}
# {'date': '2010-11-22', 'station': 'GHCND:USW00014740', 'zipcode': '06096', 'prcp_value': 0}
# {'date': '2010-11-22', 'station': 'GHCND:USW00094846', 'zipcode': '60018', 'prcp_value': 348}
# {'date': '2010-11-22', 'station': 'GHCND:USC00346659', 'zipcode': '73159', 'prcp_value': 0}
# {'date': '2010-11-23', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-11-23', 'station': 'GHCND:USC00088942', 'zipcode': '32780', 'prcp_value': 112}
# {'date': '2010-11-23', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 10}
# {'date': '2010-11-24', 'station': 'GHCND:US1FLDV0037', 'zipcode': '32218', 'prcp_value': 0}
# {'date': '2010-11-24', 'station': 'GHCND:USW00014734', 'zipcode': '07114', 'prcp_value': 0}
# {'date': '2010-11-24', 'station': 'GHCND:USW00013960', 'zipcode': '75235', 'prcp_value': 0}
# {'date': '2010-11-24', 'station': 'GHCND:USW00023234', 'zipcode': '94128', 'prcp_value': 0}
# {'date': '2010-11-24', 'station': 'GHCND:US1UTSL0085', 'zipcode': '84116', 'prcp_value': 127}
# {'date': '2010-11-26', 'station': 'GHCND:USW00023293', 'zipcode': '95110', 'prcp_value': 0}
# {'date': '2010-11-26', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 41}
# {'date': '2010-11-26', 'station': 'GHCND:USW00003102', 'zipcode': '91761', 'prcp_value': 0}
# {'date': '2010-11-26', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 43}
# {'date': '2010-11-26', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-11-26', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-11-27', 'station': 'GHCND:USW00014922', 'zipcode': '55450', 'prcp_value': 0}
# {'date': '2010-11-29', 'station': 'GHCND:USW00012916', 'zipcode': '70062', 'prcp_value': 23}
# {'date': '2010-11-30', 'station': 'GHCND:USW00014839', 'zipcode': '53207', 'prcp_value': 38}
# {'date': '2010-11-30', 'station': 'GHCND:USW00003102', 'zipcode': '91761', 'prcp_value': 0}
# {'date': '2010-11-30', 'station': 'GHCND:USW00014739', 'zipcode': '02128', 'prcp_value': 0}
# {'date': '2010-11-30', 'station': 'GHCND:US1IDPW0003', 'zipcode': '83204', 'prcp_value': 0}
# {'date': '2010-12-01', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-12-02', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-12-02', 'station': 'GHCND:USW00094741', 'zipcode': '07608', 'prcp_value': 0}
# {'date': '2010-12-02', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-12-03', 'station': 'GHCND:USW00013722', 'zipcode': '27560', 'prcp_value': 0}
# {'date': '2010-12-03', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-12-03', 'station': 'GHCND:US1ILWN0010', 'zipcode': '61109', 'prcp_value': 0}
# {'date': '2010-12-04', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-12-04', 'station': 'GHCND:USW00024229', 'zipcode': '97218', 'prcp_value': 0}
# {'date': '2010-12-04', 'station': 'GHCND:USW00013970', 'zipcode': '70807', 'prcp_value': 0}
# {'date': '2010-12-04', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-12-06', 'station': 'GHCND:USW00022536', 'zipcode': '96766', 'prcp_value': 0}
# {'date': '2010-12-07', 'station': 'GHCND:USW00093821', 'zipcode': '40213', 'prcp_value': 0}
# {'date': '2010-12-07', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-12-07', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-12-08', 'station': 'GHCND:US1TNDV0033', 'zipcode': '37214', 'prcp_value': 0}
# {'date': '2010-12-08', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-12-09', 'station': 'GHCND:USW00003102', 'zipcode': '91761', 'prcp_value': 0}
# {'date': '2010-12-11', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-12-11', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 0}
# {'date': '2010-12-11', 'station': 'GHCND:USC00041194', 'zipcode': '91505', 'prcp_value': 0}
# {'date': '2010-12-11', 'station': 'GHCND:USW00012895', 'zipcode': '34946', 'prcp_value': 0}
# {'date': '2010-12-13', 'station': 'GHCND:US1VANNC003', 'zipcode': '23602', 'prcp_value': 84}
# {'date': '2010-12-13', 'station': 'GHCND:USW00012815', 'zipcode': '32827', 'prcp_value': 0}
# {'date': '2010-12-14', 'station': 'GHCND:USW00013904', 'zipcode': '78719', 'prcp_value': 0}
# {'date': '2010-12-14', 'station': 'GHCND:US1MSHR0007', 'zipcode': '39503', 'prcp_value': 0}
# {'date': '2010-12-14', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-12-15', 'station': 'GHCND:USW00023174', 'zipcode': '90045', 'prcp_value': 0}
# {'date': '2010-12-15', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-12-16', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-12-16', 'station': 'GHCND:USW00013881', 'zipcode': '28208', 'prcp_value': 33}
# {'date': '2010-12-16', 'station': 'GHCND:USW00094789', 'zipcode': '11430', 'prcp_value': 0}
# {'date': '2010-12-16', 'station': 'GHCND:US1TXTN0023', 'zipcode': '76051', 'prcp_value': 0}
# {'date': '2010-12-17', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 137}
# {'date': '2010-12-17', 'station': 'GHCND:USW00023136', 'zipcode': '93010', 'prcp_value': 109}
# {'date': '2010-12-18', 'station': 'GHCND:US1VANNC003', 'zipcode': '23602', 'prcp_value': 8}
# {'date': '2010-12-18', 'station': 'GHCND:USC00043256', 'zipcode': '93727', 'prcp_value': 234}
# {'date': '2010-12-20', 'station': 'GHCND:USW00022536', 'zipcode': '96766', 'prcp_value': 76}
# {'date': '2010-12-20', 'station': 'GHCND:USW00012960', 'zipcode': '77032', 'prcp_value': 0}
# {'date': '2010-12-21', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 28}
# {'date': '2010-12-22', 'station': 'GHCND:USW00012921', 'zipcode': '78216', 'prcp_value': 3}
# {'date': '2010-12-22', 'station': 'GHCND:USC00446147', 'zipcode': '23502', 'prcp_value': 0}
# {'date': '2010-12-22', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 112}
# {'date': '2010-12-23', 'station': 'GHCND:USW00023160', 'zipcode': '85756', 'prcp_value': 41}
# {'date': '2010-12-24', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-12-24', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-12-24', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-12-24', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 3}
# {'date': '2010-12-25', 'station': 'GHCND:USC00111577', 'zipcode': '60638', 'prcp_value': 13}
# {'date': '2010-12-25', 'station': 'GHCND:USC00083163', 'zipcode': '33315', 'prcp_value': 0}
# {'date': '2010-12-26', 'station': 'GHCND:USW00012844', 'zipcode': '33406', 'prcp_value': 81}
# {'date': '2010-12-26', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 10}
# {'date': '2010-12-27', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-12-28', 'station': 'GHCND:USC00086078', 'zipcode': '34104', 'prcp_value': 0}
# {'date': '2010-12-28', 'station': 'GHCND:USW00093067', 'zipcode': '80112', 'prcp_value': 0}
# {'date': '2010-12-29', 'station': 'GHCND:USW00012842', 'zipcode': '33607', 'prcp_value': 0}
# {'date': '2010-12-30', 'station': 'GHCND:USW00013970', 'zipcode': '70807', 'prcp_value': 30}
# {'date': '2010-12-30', 'station': 'GHCND:USW00012894', 'zipcode': '33913', 'prcp_value': 0}
# {'date': '2010-12-30', 'station': 'GHCND:USW00014732', 'zipcode': '11371', 'prcp_value': 0}
# {'date': '2010-12-30', 'station': 'GHCND:USC00421144', 'zipcode': '84083', 'prcp_value': 13}
# {'date': '2010-12-31', 'station': 'GHCND:USW00093225', 'zipcode': '95837', 'prcp_value': 0}
# {'date': '2010-12-31', 'station': 'GHCND:USW00003017', 'zipcode': '80249', 'prcp_value': 30}

# %%
df_zip_date_2010[df_zip_date_2010['incident_date'] == '2010-09-06']
# Out:
#       Unnamed: 0  Record ID  Incident Year  Incident Month  Incident Day  \
# 1231      113404     306097           2010               9             6
# 1232      113405     306198           2010               9             6
# 1233      113407     306836           2010               9             6
# 1234      113408     306837           2010               9             6
# 1235      113422     307002           2010               9             6
# 1236      113423     307004           2010               9             6
# 1237      113428     307012           2010               9             6
# 1238      113433     307017           2010               9             6
# 1239      113438     307013           2010               9             6
#
#      Operator ID              Operator   Aircraft Aircraft Type Aircraft Make  \
# 1231         AAY         ALLEGIANT AIR      MD-83             A           583
# 1232         BUS              BUSINESS      C-172             A           226
# 1233         AAL     AMERICAN AIRLINES  B-737-800             A           148
# 1234         AAL     AMERICAN AIRLINES      MD-82             A           583
# 1235         COA  CONTINENTAL AIRLINES  B-757-200             A           148
# 1236         HAL          HAWAIIAN AIR  B-717-200             A           148
# 1237         SWA    SOUTHWEST AIRLINES  B-737-300             A           148
# 1238         AWE            US AIRWAYS      A-319             A           04A
# 1239         SWA    SOUTHWEST AIRLINES  B-737-300             A           148
#
#       ...            type                                               name  \
# 1231  ...  medium_airport                         Bismarck Municipal Airport
# 1232  ...   small_airport                            Harrison County Airport
# 1233  ...   large_airport                        Miami International Airport
# 1234  ...   large_airport               Chicago O'Hare International Airport
# 1235  ...   large_airport               Newark Liberty International Airport
# 1236  ...   large_airport              Daniel K Inouye International Airport
# 1237  ...   large_airport                            William P Hobby Airport
# 1238  ...   large_airport  General Edward Lawrence Logan International Ai...
# 1239  ...   large_airport         Metropolitan Oakland International Airport
#
#      elevation_ft municipality                              coordinates  \
# 1231       1661.0     Bismarck  -100.74600219726562, 46.772701263427734
# 1232        357.0     Marshall             -94.307800293, 32.5205001831
# 1233          8.0        Miami    -80.29060363769531, 25.79319953918457
# 1234        672.0      Chicago                        -87.9048, 41.9786
# 1235         18.0       Newark     -74.168701171875, 40.692501068115234
# 1236         13.0     Honolulu                    -157.924228, 21.32062
# 1237         46.0      Houston                -95.27890015, 29.64539909
# 1238         20.0       Boston                -71.00520325, 42.36429977
# 1239          9.0      Oakland                   -122.221001, 37.721298
#
#                      long                  lat                 lat_  \
# 1231  -100.74600219726562   46.772701263427734   46.772701263427734
# 1232        -94.307800293        32.5205001831        32.5205001831
# 1233   -80.29060363769531    25.79319953918457    25.79319953918457
# 1234             -87.9048              41.9786              41.9786
# 1235     -74.168701171875   40.692501068115234   40.692501068115234
# 1236          -157.924228             21.32062             21.32062
# 1237         -95.27890015          29.64539909          29.64539909
# 1238         -71.00520325          42.36429977          42.36429977
# 1239          -122.221001            37.721298            37.721298
#
#                     long_  zipcode
# 1231  -100.74600219726562    58504
# 1232        -94.307800293    75672
# 1233   -80.29060363769531    33142
# 1234             -87.9048    60018
# 1235     -74.168701171875    07114
# 1236          -157.924228    96818
# 1237         -95.27890015    77061
# 1238         -71.00520325    02128
# 1239          -122.221001    94621
#
# [9 rows x 38 columns]
